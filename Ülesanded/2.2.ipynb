# %%
import pandas as pd
path='C:/Users/eleli/Poder_vc_DR3_input_v2.csv'
data_icrs=pd.read_csv(path)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
import sys
sys.path.append('../gaia_tools')
from data_analysis import get_transformed_data

# %% [markdown]
# #Ül1

# %%
df1=get_transformed_data(data_icrs)

# %%
df1
# Out:
#                   x           y           z        v_x         v_y        v_z
# 0      -8294.193367    8.129045 -112.628108  82.490294  154.852913  36.946622
# 1      -8319.079954    9.055325 -136.010702 -21.669528  188.075947   4.900133
# 2      -8280.202406    8.847011  -95.857006  30.742115  235.957740  -7.330141
# 3      -8333.850616   15.413974 -154.114467   6.388679  206.677689 -13.685563
# 4      -8354.940304   15.353391 -151.026097  -0.867458  231.401924 -16.340025
# ...             ...         ...         ...        ...         ...        ...
# 665655 -7999.050910  189.833582 -133.115224  22.632111  231.211456  -1.838349
# 665656 -7877.485578  315.746741 -224.534694  31.434347  242.026253  10.370387
# 665657 -7989.570263  205.339851 -137.416389  49.242086  201.475737 -13.035103
# 665658 -7996.820723  197.222715 -126.282306  24.577013  244.639682   4.135062
# 665659 -7990.855341  210.588974 -138.945717  17.083254  264.112140   3.227044
#
# [665660 rows x 6 columns]

# %%
get_transformed_data
# Out:
# <function data_analysis.get_transformed_data(data_icrs, include_cylindrical=False, z_0=17, r_0=8178, v_sun=array([[ 11.1 ],
#        [232.24],
#        [  7.25]]), debug=False, is_source_included=False, is_bayes=False)>

# %%
df2=get_transformed_data(data_icrs, z_0=17, r_0=8178, v_sun=np.array([[ 11.1 ],
       [332.24],
       [  7.25]]))
df2
# Out:
#                   x           y           z        v_x         v_y        v_z
# 0      -8294.193367    8.129045 -112.628108  82.490294  254.852913  36.946622
# 1      -8319.079954    9.055325 -136.010702 -21.669528  288.075947   4.900133
# 2      -8280.202406    8.847011  -95.857006  30.742115  335.957740  -7.330141
# 3      -8333.850616   15.413974 -154.114467   6.388679  306.677689 -13.685563
# 4      -8354.940304   15.353391 -151.026097  -0.867458  331.401924 -16.340025
# ...             ...         ...         ...        ...         ...        ...
# 665655 -7999.050910  189.833582 -133.115224  22.632111  331.211456  -1.838349
# 665656 -7877.485578  315.746741 -224.534694  31.434347  342.026253  10.370387
# 665657 -7989.570263  205.339851 -137.416389  49.242086  301.475737 -13.035103
# 665658 -7996.820723  197.222715 -126.282306  24.577013  344.639682   4.135062
# 665659 -7990.855341  210.588974 -138.945717  17.083254  364.112140   3.227044
#
# [665660 rows x 6 columns]

# %%
fig, ax=plt.subplots()
ax.hist(df1.v_y,bins=200) 
ax.hist(df2.v_y,bins=200)
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         2.0000e+00, 1.0000e+00, 0.0000e+00, 4.0000e+00, 1.0000e+00,
#         1.0000e+00, 2.0000e+00, 4.0000e+00, 0.0000e+00, 1.0000e+00,
#         5.0000e+00, 6.0000e+00, 7.0000e+00, 1.0000e+00, 4.0000e+00,
#         4.0000e+00, 1.2000e+01, 5.0000e+00, 8.0000e+00, 7.0000e+00,
#         4.0000e+00, 9.0000e+00, 9.0000e+00, 8.0000e+00, 1.8000e+01,
#         1.0000e+01, 1.3000e+01, 1.6000e+01, 1.6000e+01, 1.8000e+01,
#         1.9000e+01, 2.8000e+01, 2.5000e+01, 3.4000e+01, 3.3000e+01,
#         3.9000e+01, 3.6000e+01, 4.1000e+01, 4.6000e+01, 6.0000e+01,
#         5.7000e+01, 5.8000e+01, 5.1000e+01, 8.0000e+01, 8.4000e+01,
#         1.0400e+02, 1.0500e+02, 1.3200e+02, 1.1600e+02, 1.2400e+02,
# ...

# %% [markdown]
# #Ül2

# %%
dff=get_transformed_data(data_icrs)

# %%
Vx=np.array(dff.v_x)
Vx_mod=np.linalg.norm(Vx)
Vx_mod
Vx.shape
# Out:
# (665660,)

# %%
Vy=np.array(dff.v_y)
Vy_mod=np.linalg.norm(Vy)
Vy_mod
# Out:
# 168674.08953279586

# %%
Vz=np.array(dff.v_z)
Vz_mod=np.linalg.norm(Vz)
Vz_mod
# Out:
# 15772.322493737785

# %%
import math

# %%
V=np.sqrt(dff.v_x ** 2+dff.v_y ** 2+dff.v_z** 2)
V
# Out:
# 0         179.301775
# 1         189.383584
# 2         238.064831
# 3         207.228803
# 4         231.979739
#              ...
# 665655    232.323760
# 665656    244.279288
# 665657    207.815229
# 665658    245.905881
# 665659    264.683724
# Length: 665660, dtype: float64

# %%
fig, ax=plt.subplots()
ax.hist(V,bins=500)
# Out:
# (array([1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         3.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         4.000e+00, 2.000e+00, 3.000e+00, 0.000e+00, 4.000e+00, 1.000e+00,
#         0.000e+00, 3.000e+00, 0.000e+00, 3.000e+00, 2.000e+00, 2.000e+00,
#         2.000e+00, 5.000e+00, 2.000e+00, 1.000e+00, 5.000e+00, 1.000e+00,
#         2.000e+00, 1.000e+00, 3.000e+00, 5.000e+00, 5.000e+00, 4.000e+00,
#         5.000e+00, 3.000e+00, 5.000e+00, 3.000e+00, 3.000e+00, 3.000e+00,
# ...

# %% [markdown]
# #Ül3

# %%
p=get_transformed_data(data_icrs,include_cylindrical = True)
p
# Out:
#                   x           y           z        v_x         v_y        v_z  \
# 0      -8294.193367    8.129045 -112.628108  82.490294  154.852913  36.946622
# 1      -8319.079954    9.055325 -136.010702 -21.669528  188.075947   4.900133
# 2      -8280.202406    8.847011  -95.857006  30.742115  235.957740  -7.330141
# 3      -8333.850616   15.413974 -154.114467   6.388679  206.677689 -13.685563
# 4      -8354.940304   15.353391 -151.026097  -0.867458  231.401924 -16.340025
# ...             ...         ...         ...        ...         ...        ...
# 665655 -7999.050910  189.833582 -133.115224  22.632111  231.211456  -1.838349
# 665656 -7877.485578  315.746741 -224.534694  31.434347  242.026253  10.370387
# 665657 -7989.570263  205.339851 -137.416389  49.242086  201.475737 -13.035103
# 665658 -7996.820723  197.222715 -126.282306  24.577013  244.639682   4.135062
# 665659 -7990.855341  210.588974 -138.945717  17.083254  264.112140   3.227044
#
# ...

# %%
fig, ax=plt.subplots()
ax.hist(p.r,bins=200)
plt.xlabel('r [pc]')
# Out:
# Text(0.5, 0, 'r [pc]')

# %%
fig, ax=plt.subplots()
ax.hist(p.z,bins=200)
plt.xlabel('z [pc]')
# Out:
# Text(0.5, 0, 'z [pc]')

# %%
fig, ax=plt.subplots()
ax.hist2d(p.r,p.v_phi,bins=200)
plt.xlabel('r [pc]')
plt.ylabel('v_phi [km/s]')
# Out:
# Text(0, 0.5, 'v_phi []')
