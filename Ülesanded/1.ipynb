# %% [markdown]
# #Ül1

# %%
import pandas as pd

# %%
path='C:/Users/eleli/Poder_vc_DR3_input_v2.csv'
df=pd.read_csv(path)

# %%
df.head()
# Out:
#           source_id         ra       dec        rgeo      b_rgeo      B_rgeo  \
# 0   132667245587072  45.072796  0.969971  173.284653  172.683990  173.952347
# 1   250246270117248  45.794345  1.368092  206.803787  205.693710  207.794327
# 2   454514914751488  44.857643  1.651125  152.416534  148.039703  155.904755
# 3  1301929142132608  44.655749  2.120449  230.318222  228.889191  231.673080
# 4  3188656735589888  47.893246  4.723239  242.655655  241.226486  244.326447
#
#       b_rpgeo     B_rpgeo  ra_error  dec_error  ...  b_rGSPPhot   B_rGSPPhot  \
# 0  172.806274  173.960129    0.0168     0.0177  ...    171.5481     172.7822
# 1  206.021637  208.067200    0.0202     0.0199  ...    208.1446     210.0136
# 2  146.656723  155.209595    0.1433     0.1492  ...    165.1155     175.9081
# 3  228.467499  231.467667    0.0186     0.0189  ...    231.7378     253.0253
# 4  241.199051  244.316528    0.0222     0.0192  ...    239.8184     243.3522
#
# ...

# %%
df.shape
# Out:
# (665660, 34)

# %%
d=1/df.parallax

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
fig, ax=plt.subplots()
ax.hist(d,bins=100)
plt.xlim(0,5)
# Out:
# (0.0, 5.0)

# %%
a=np.array(d)
a
# Out:
# array([0.17428283, 0.20833333, 0.15252505, ..., 0.31860324, 0.30372058,
#        0.32199897])

# %%
length=a.size
length
# Out:
# 665660

# %%
summa=a.sum()
summa
# Out:
# 1261583.951964851

# %%
d.sum()/len(d)
# Out:
# 1.8952377369300408

# %%
keskmine=summa/length
keskmine
# Out:
# 1.8952377369300408

# %%
np.mean(d)
# Out:
# 1.8952377369300408

# %% [markdown]
# #Ül2

# %%
v_r=df.radial_velocity

# %%
fig, ax=plt.subplots()
ax.hist(v_r,bins=100)
# Out:
# (array([2.0000e+00, 6.0000e+00, 3.0000e+00, 3.0000e+00, 1.0000e+00,
#         1.2000e+01, 7.0000e+00, 1.4000e+01, 2.1000e+01, 1.5000e+01,
#         2.6000e+01, 2.5000e+01, 4.2000e+01, 4.4000e+01, 6.9000e+01,
#         1.0000e+02, 8.9000e+01, 1.6500e+02, 1.9800e+02, 2.6100e+02,
#         3.3700e+02, 4.3500e+02, 5.6300e+02, 7.0200e+02, 9.5300e+02,
#         1.2330e+03, 1.5900e+03, 2.1190e+03, 2.5820e+03, 3.2260e+03,
#         4.1330e+03, 5.1120e+03, 6.1510e+03, 7.5760e+03, 8.9740e+03,
#         1.0737e+04, 1.2531e+04, 1.4550e+04, 1.6770e+04, 1.9394e+04,
#         2.1231e+04, 2.3585e+04, 2.4958e+04, 2.6478e+04, 2.7525e+04,
#         2.7857e+04, 2.8174e+04, 2.8630e+04, 2.8245e+04, 2.7662e+04,
#         2.7022e+04, 2.5802e+04, 2.4489e+04, 2.2688e+04, 2.1374e+04,
#         1.9609e+04, 1.7831e+04, 1.6640e+04, 1.4735e+04, 1.3336e+04,
#         1.1734e+04, 1.0378e+04, 9.0990e+03, 7.7700e+03, 6.9020e+03,
#         5.5850e+03, 4.9280e+03, 4.0160e+03, 3.3920e+03, 2.7400e+03,
# ...

# %%
b=np.array(v_r)
bl=b.size
bs=b.sum()
bk=bs/bl
bk
# Out:
# -4.784924916624106

# %%
np.mean(v_r)
# Out:
# -4.784924916624106

# %% [markdown]
# #Ül3

# %%
x=np.array(df.ra)
y=np.array(df.dec)

# %%
fig, ax=plt.subplots()
ax.hist2d(x,y,bins=100)
ax.set_xlabel(r'$\alpha$ [deg]')
ax.set_ylabel(r'$\delta$ [deg]')
# Out:
# Text(0, 0.5, ' $\\delta$ [deg]')
# Error in callback <function _draw_all_if_interactive at 0x0000020E40AB54E0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# ...

# %%
pwd
# Out:
# 'c:\\Users\\eleli\\repos\\gaia-tools\\Ülesanded'
