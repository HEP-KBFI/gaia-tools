# %% [markdown]
# # Importing

# %%
#import cupy as cp
import pandas as pd
import numpy as np
from numba import jit

# Disable if running on GPU
from numba import jit, config
config.DISABLE_JIT = True
import cProfile
import sys
sys.path.append("../gaia_tools/")
import transformation_constants
import transformation_functions
import data_analysis
import covariance_generation as cov

# %%
# LOCAL
# print('Grabbing needed columns')
# icrs_data = pd.read_csv('/home/svenpoder/DATA/Gaia_2MASS Data_DR2/gaia_rv_data_bayes.csv', nrows = 10)
# print('Importing DR3')
# path = '/home/svenpoder/DATA/Gaia_DR3/GaiaDR3_RV_RGB_fidelity.csv'
# gaia_dr3 = pd.read_csv(path)
# icrs_data = gaia_dr3[icrs_data.columns]


# REMOTE
print('Grabbing needed columns')
icrs_data = pd.read_csv('/local/sven/gaia_tools_data/gaia_rv_data_bayes.csv', nrows = 10)
print('Importing DR3')
path = '/local/mariacst/2022_v0_project/data/GaiaDR3_RV_RGB_fidelity.csv'
gaia_dr3 = pd.read_csv(path, nrows=1e5)
icrs_data = gaia_dr3[icrs_data.columns]
# Out:
# Grabbing needed columns
# Importing DR3

# %%
## TRANSFORMATION CONSTANTS
v_sun = transformation_constants.V_SUN

r_0 = 8277
z_0 = 25

v_sun[0][0] = 11.1
v_sun[1][0] = 251.5*(r_0/8277)
v_sun[2][0] = 8.59*(r_0/8277)

# %%
galcen_data = data_analysis.get_transformed_data(icrs_data,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)

galcen_data = galcen_data[(galcen_data.r < 15000) & (galcen_data.r > 5000)]
galcen_data = galcen_data[(galcen_data.z < 200) & (galcen_data.z > -200)]
galcen_data.reset_index(inplace=True, drop=True)

icrs_data = icrs_data.merge(galcen_data, on='source_id')[icrs_data.columns]
print("Final size of sample {}".format(galcen_data.shape))
galcen_data.columns
# Out:
# Starting galactocentric transformation loop over all data points..
# Time elapsed for data coordinate transformation: 0.2561889961361885 sec
# Final size of sample (37921, 11)
# Index(['x', 'y', 'z', 'v_x', 'v_y', 'v_z', 'r', 'phi', 'v_r', 'v_phi',
#        'source_id'],
#       dtype='object')

# %%
# Generate covariance matrix in ICRS
C_icrs = cov.generate_covmat(icrs_data)

# %%
# Export data to GPU

trans_needed_columns = ['source_id', 'ra', 'dec', 'r_est', 'pmra', 'pmdec', 'radial_velocity',]
icrs_gpu = cp.asarray(icrs_data[trans_needed_columns], dtype=cp.float32)

galcen_gpu = cp.asarray(galcen_data, dtype=cp.float32)
galcen_gpu.dtype

C_icrs_gpu = cp.asarray(C_icrs, dtype=cp.float32)

# %% [markdown]
# # Coordinate Transformation

# %% [markdown]
# ## Coordinate Transformation Prototype

# %%
def get_H_matrix_gpu(Z_0, R_0):
    
    if(Z_0/R_0 is None):
        print("Something went wrong! No values for either Z_0 or R_0 were found!")
        return
   
    THETA_0 = np.arcsin(Z_0/R_0)

    # Defining constants to reduce process time
    costheta = np.cos(THETA_0)
    sintheta = np.sin(THETA_0)

    H = cp.array([[costheta, 0, sintheta],
                 [0, 1, 0],
                 [-sintheta, 0, costheta]], dtype=cp.float32)

    return H

def get_b_matrix_gpu(ra, dec):

    #B = np.array([[cosra*cosdec, -sinra, -cosra*sindec],
    #         [sinra*cosdec, cosra, -sinra*sindec],
    #         [sindec, np.zeros(n), cosdec]])
    
    
    # Add check if ra == dec
    
    n = len(ra)

    B = cp.zeros((n, 3, 3), dtype=cp.float32)
    
    # Defining constants to reduce process time
    cosra = np.cos(ra)
    cosdec = np.cos(dec)
    sinra = np.sin(ra)
    sindec = np.sin(dec)

    B[:, 0, 0] = cosra*cosdec
    B[:, 0, 1] = -sinra
    B[:, 0, 2] = -cosra*sindec
    
    B[:, 1, 0] = sinra*cosdec
    B[:, 1, 1] = cosra
    B[:, 1, 2] = -sinra*sindec
    
    B[:, 2, 0] = sindec
    B[:, 2, 2] = cosdec
    
    # Returns array of B matrices - one for each data point
    return B


def get_cylindrical_velocity_matrix_gpu(phi):
   
    n = len(phi)

    sin_phi = np.sin(phi).ravel()
    cos_phi = np.cos(phi).ravel()

    M = cp.array([[cos_phi, sin_phi, cp.zeros(n)],
         [-sin_phi, cos_phi, cp.zeros(n)],
         [cp.zeros(n), cp.zeros(n), cp.ones(n)]], dtype=cp.float32)

    M = M.T.reshape(n,3,3, order = 'A').swapaxes(1,2)

    # Returns array of matrices - one for each data point
    return M

# %%
from transformation_constants import A, k1, k2

A = cp.asarray(A, dtype=cp.float32)

def transform_coordinates_galactocentric_gpu(data_icrs, 
                                        z_0 = transformation_constants.Z_0, 
                                        r_0 = transformation_constants.R_0, 
                                        is_bayes = False):
    """This function uses input ICRS data and outputs data in cartesian (x,y,z) coordinates and in galactocentric frame of reference.

    Args:
        data_icrs (DataFrame): DataFrame of ICRS coordinates
        z_0 (float, optional): Sun's height over Galactic plane. Defaults to transformation_constants.Z_0.
        r_0 (float, optional): Sun's Galactocentric distance. Defaults to transformation_constants.R_0.
        is_bayes (bool, optional): Flag for using pre-computed (Bayesian) distance estimates. Defaults to False.

    Returns:
        ndarray: Array of Cartesian coordinates of shape (n,3,1).
    """

    #TODO: Add ASSERT checks on function input parameters.
    # ra dec can only be in a specific range

    # Number of data points
    n = len(data_icrs)

    # Going from DEG -> RAD
    ra = np.deg2rad(data_icrs[:,1])
    dec = np.deg2rad(data_icrs[:,2])

    if(is_bayes):
        c1 = data_icrs[:,3]

    else:
        # from kpc -> pc
        k1 = transformation_constants.k1

        # Declaring constants to reduce process time
        c1 = k1/data_icrs[:,3]

    cosdec = np.cos(dec)

    # Initial cartesian coordinate vector in ICRS
    coordxyz_ICRS = cp.asarray([[(c1)*np.cos(ra)*cosdec],
                      [(c1)*np.sin(ra)*cosdec],
                       [(c1)*np.sin(dec)]])

    coordxyz_ICRS = coordxyz_ICRS.T.reshape(n,3,1, order = 'A')

    # Using M1, M2, M3 for transparency in case of bugs
    M1 = cp.matmul(A,coordxyz_ICRS)
    M2 = M1 - cp.asarray([[r_0],
                        [0],
                        [0]], dtype=cp.float32)

    M3 = cp.matmul(get_H_matrix_gpu(z_0, r_0),M2)
   

    # Return is a np.array of shape (n,3,1)
    return M3

'''
This function uses input ICRS data and outputs data in cartesian (v_x,v_y,v_z) velocity vector components and in galactocentric frame of reference.
'''
def transform_velocities_galactocentric(data_icrs, 
                                z_0 = transformation_constants.Z_0, 
                                r_0 = transformation_constants.R_0, 
                                v_sun = transformation_constants.V_SUN, 
                                is_bayes = False):
    """Function for transforming proper motions with radial velocities to Cartesian velocity vector components in galactocentric frame.

    Args:
        data_icrs (DataFrame): DataFrame in ICRS
        z_0 (float, optional): Sun's position over Galactic plane. Defaults to transformation_constants.Z_0.
        r_0 (float, optional): Sun's Galactocentric distance. Defaults to transformation_constants.R_0.
        v_sun (tuple, optional): Sun's velocity vector. Defaults to transformation_constants.V_SUN.
        is_bayes (bool, optional): Flag for using pre-computed (Bayesian) distance estimates. Defaults to False.

    Returns:
        ndarray: Cartesian velocity components of shape (n,3,1)
    """
    # Number of data points
    n = len(data_icrs)

    # Going from DEG -> RAD
    ra = np.deg2rad(data_icrs[:,1])
    dec = np.deg2rad(data_icrs[:,2])

    # from 1/yr -> km/s
    k2 = transformation_constants.k2

    if(is_bayes):
        # Assign r estimates to c2
        c2 = k2*(data_icrs[:,3]/1000)

    else:
        # Declaring constants to reduce process time
        c2 = k2/data_icrs[:,3]

    # Initial velocity vector in ICRS in units km/s
    v_ICRS = cp.asarray([[data_icrs[:,6]],
                      [(c2)*data_icrs[:,4]],
                      [(c2)*data_icrs[:,5]]])

    v_ICRS = v_ICRS.T.reshape(n,3,1, order = 'A')

    B = get_b_matrix_gpu(ra, dec)
    B = B.reshape(n,3,3, order = 'A')

    # Using M1, M2, M3, .. for transparency in case of bugs
    M2 = cp.matmul(A, cp.matmul(B,v_ICRS))
    M3 = cp.matmul(get_H_matrix_gpu(z_0, r_0), M2)

    # Return is a np.array of shape (n,3,1)
    M4 = M3 + cp.asarray(v_sun, dtype=cp.float32)
    return M4

def transform_velocities_cylindrical(velocities_xyz, phi):
    """Transforms Cartesian velocities to cylindrical

    Args:
        velocities_xyz (np.array): Cartesian velocity array
        phi (np.array): Array of phi coordinates

    Returns:
        np.array: Array of cylindrical velocity components.
    """
    v_cylindrical = cp.matmul(get_cylindrical_velocity_matrix_gpu(phi), velocities_xyz)

    return v_cylindrical


def get_transformed_data(data_icrs,
                        include_cylindrical = False,
                        z_0 = transformation_constants.Z_0,
                        r_0 = transformation_constants.R_0,
                        v_sun = transformation_constants.V_SUN,
                        debug = False,
                        is_source_included = False,
                        is_bayes = False):
    
    # Coordinate vector in galactocentric frame in xyz
    coords =  transform_coordinates_galactocentric_gpu(data_icrs, z_0, r_0, is_bayes)
    # # Velocity vector in galactocentric frame in xyz
    velocities = transform_velocities_galactocentric(data_icrs, z_0, r_0, v_sun, is_bayes)
    
    if(include_cylindrical):

        # Using arctan2 which is defined in range [-pi ; pi]
        phi = np.arctan2(coords[:,1],coords[:,0])
        vel_cyl = transform_velocities_cylindrical(velocities, phi)
        coords_cyl = (np.sqrt(coords[:,0]**2 + coords[:,1]**2), phi)
        
    galcen_out = cp.concatenate((cp.squeeze(coords, axis=2), cp.squeeze(velocities, axis=2)), axis=1)
    coords_cyl = cp.squeeze(cp.asarray(coords_cyl).T, axis=0)
    vel_cyl = cp.squeeze(vel_cyl, axis=2)[:,0:2]
    galcen_out = cp.concatenate((galcen_out, coords_cyl, vel_cyl), axis=1)
    
    return galcen_out

# %%
galcen_data_gpu = get_transformed_data(icrs_gpu,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)
galcen_data_gpu.dtype
# Out:
# dtype('float32')

# %%
galcen_data = data_analysis.get_transformed_data(icrs_data,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)
# Out:
# Starting galactocentric transformation loop over all data points..
# Time elapsed for data coordinate transformation: 0.6289024209991112 sec

# %% [markdown]
# ## Testing New Transformation

# %%
trans_needed_columns = ['source_id', 'ra', 'dec', 'r_est', 'pmra', 'pmdec', 'radial_velocity']
icrs_cpu = icrs_data[trans_needed_columns].to_numpy()
icrs_gpu = cp.asarray(icrs_data[trans_needed_columns], dtype=cp.float32)

# Old function
galcen_data = data_analysis.get_transformed_data(icrs_data,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)

# New function
NUMPY_LIB = np
galcen_data_new_cpu = transformation_functions.get_transformed_data(icrs_cpu,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True, 
                                       NUMPY_LIB = NUMPY_LIB)



NUMPY_LIB = cp
dtype = cp.float32
galcen_data_new_gpu = transformation_functions.get_transformed_data(icrs_gpu,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True, 
                                       NUMPY_LIB = NUMPY_LIB,
                                       dtype = dtype)
# Out:
# Starting galactocentric transformation loop over all data points..
# Time elapsed for data coordinate transformation: 0.6237074750001739 sec

# %%
print(galcen_data.iloc[0].to_numpy())
print(galcen_data_new_cpu[0])
print(galcen_data_new_gpu[0])

print(galcen_data.shape)
print(galcen_data_new_cpu.shape)
print(galcen_data_new_gpu.shape)

print(galcen_data.dtypes)
print(galcen_data_new_cpu.dtype)
print(galcen_data_new_gpu.dtype)
# Out:
# [-8.39269568e+03  8.08717082e+00 -1.03851431e+02  8.24023689e+01
#   1.74493940e+02  3.83473567e+01  8.39269958e+03  3.14062906e+00
#  -8.22341890e+01 -1.74573262e+02  1.32667246e+14]
# [-8.39269568e+03  8.08717082e+00 -1.03851431e+02  8.24023689e+01
#   1.74493940e+02  3.83473567e+01  8.39269958e+03  3.14062906e+00
#  -8.22341890e+01 -1.74573262e+02]
# [-8.39269629e+03  8.08716774e+00 -1.03851425e+02  8.24023743e+01
#   1.74493942e+02  3.83473511e+01  8.39269922e+03  3.14062905e+00
#  -8.22341919e+01 -1.74573273e+02]
# (1694972, 11)
# (1694972, 10)
# (1694972, 10)
# x            float64
# y            float64
# z            float64
# v_x          float64
# v_y          float64
# v_z          float64
# r            float64
# phi          float64
# v_r          float64
# v_phi        float64
# source_id      int64
# dtype: object
# float64
# float32

# %%
icrs_data.columns
# Out:
# Index(['source_id', 'ra', 'ra_error', 'dec', 'dec_error', 'parallax',
#        'parallax_error', 'pmra', 'pmra_error', 'pmdec', 'pmdec_error',
#        'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr',
#        'dec_parallax_corr', 'dec_pmra_corr', 'dec_pmdec_corr',
#        'parallax_pmra_corr', 'parallax_pmdec_corr', 'pmra_pmdec_corr',
#        'radial_velocity', 'radial_velocity_error', 'r_est'],
#       dtype='object')

# %% [markdown]
# ## Profiling Transformation

# %%
def tranf_func_gpu():

    galcen_data_gpu = transformation_functions.get_transformed_data(icrs_gpu,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True, 
                                       NUMPY_LIB = NUMPY_LIB,
                                       dtype = dtype)

# %%
def tranf_func():
    galcen_data = data_analysis.get_transformed_data(icrs_data,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)

# %%
cProfile.run('tranf_func_gpu()')
# Out:
# here
#          1000 function calls in 0.007 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 797637153.py:1(tranf_func_gpu)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(can_cast)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(min_scalar_type)
#         1    0.000    0.000    0.007    0.007 <string>:1(<module>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:194(_determine_from_args)
#        18    0.000    0.000    0.000    0.000 _gufuncs.py:196(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:253(determine_dtype)
#         6    0.000    0.000    0.002    0.000 _gufuncs.py:390(_apply_func_to_inputs)
#        12    0.000    0.000    0.000    0.000 _gufuncs.py:416(_transpose_element)
#        36    0.000    0.000    0.000    0.000 _gufuncs.py:417(<genexpr>)
#        20    0.000    0.000    0.000    0.000 _gufuncs.py:419(<genexpr>)
#         6    0.000    0.000    0.001    0.000 _gufuncs.py:424(_get_args_transposed)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:46(_validate_normalize_axes)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:473(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:474(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:478(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:479(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:484(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:493(<listcomp>)
#        24    0.000    0.000    0.000    0.000 _gufuncs.py:494(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:500(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:523(_determine_order)
#         6    0.000    0.000    0.003    0.000 _gufuncs.py:541(__call__)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:65(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:665(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:667(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:93(<listcomp>)
#         6    0.000    0.000    0.000    0.000 _gufuncs.py:95(<listcomp>)
#        12    0.000    0.000    0.000    0.000 _internal.py:250(__init__)
#        12    0.000    0.000    0.000    0.000 _internal.py:304(data)
#         1    0.000    0.000    0.000    0.000 basic.py:138(ones)
#         5    0.000    0.000    0.000    0.000 basic.py:196(zeros)
#         6    0.000    0.000    0.000    0.000 basic.py:7(empty)
#         4    0.000    0.000    0.000    0.000 dims.py:151(squeeze)
#         7    0.000    0.000    0.001    0.000 from_data.py:49(asarray)
#         3    0.000    0.000    0.000    0.000 from_data.py:7(array)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         2    0.000    0.000    0.000    0.000 join.py:35(concatenate)
#        16    0.000    0.000    0.000    0.000 multiarray.py:498(can_cast)
#         4    0.000    0.000    0.000    0.000 multiarray.py:613(min_scalar_type)
#        29    0.000    0.000    0.000    0.000 numeric.py:1859(isscalar)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1126(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         1    0.000    0.000    0.000    0.000 transformation_constants.py:112(get_cylindrical_velocity_matrix)
#         2    0.000    0.000    0.000    0.000 transformation_constants.py:46(get_A_matrix)
#         2    0.000    0.000    0.000    0.000 transformation_constants.py:55(get_H_matrix)
#         1    0.000    0.000    0.001    0.001 transformation_constants.py:79(get_b_matrix)
#         1    0.000    0.000    0.001    0.001 transformation_functions.py:122(transform_velocities_cylindrical)
#         1    0.000    0.000    0.007    0.007 transformation_functions.py:137(get_transformed_data)
#         1    0.001    0.001    0.003    0.003 transformation_functions.py:6(transform_coordinates_galactocentric)
#         1    0.000    0.000    0.002    0.002 transformation_functions.py:66(transform_velocities_galactocentric)
#         1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       228    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        36    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         6    0.002    0.000    0.002    0.000 {built-in method cupy._core._routines_linalg.matmul}
#        12    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation.broadcast_to}
#         2    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation.concatenate_method}
#        10    0.001    0.000    0.001    0.000 {built-in method cupy._core.core.array}
#         6    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._broadcast_shapes}
#         6    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._get_strides_for_order_K}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         6    0.000    0.000    0.000    0.000 {method '_set_shape_and_strides' of 'cupy._core.core._ndarray_base' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        54    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fill' of 'cupy._core.core._ndarray_base' objects}
#        36    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'memset_async' of 'cupy.cuda.memory.MemoryPointer' objects}
#        48    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.000    0.000 {method 'squeeze' of 'cupy._core.core._ndarray_base' objects}
#         1    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'cupy._core.core._ndarray_base' objects}
#        18    0.000    0.000    0.000    0.000 {method 'transpose' of 'cupy._core.core._ndarray_base' objects}
#        24    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#        12    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
cProfile.run('tranf_func()')
# Out:
# Starting galactocentric transformation loop over all data points..
# here
# Time elapsed for data coordinate transformation: 0.6294019090018992 sec
#          6837 function calls (6729 primitive calls) in 0.630 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.629    0.629 4055506708.py:1(tranf_func)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         1    0.000    0.000    0.002    0.002 <__array_function__ internals>:177(array_equal)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#        16    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(squeeze)
#        28    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         1    0.000    0.000    0.629    0.629 <string>:1(<module>)
#         9    0.000    0.000    0.000    0.000 __init__.py:152(align_method_SERIES)
#         1    0.000    0.000    0.000    0.000 _asarray.py:111(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:22(require)
#         3    0.000    0.000    0.000    0.000 _decorators.py:214(_format_argument_list)
#         3    0.000    0.000    0.033    0.011 _decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         1    0.000    0.000    0.000    0.000 _dtype.py:314(_name_includes_bit_suffix)
#         1    0.000    0.000    0.000    0.000 _dtype.py:328(_name_get)
#         1    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#        18    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#        18    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         9    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         9    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         9    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         7    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 api.py:102(<listcomp>)
#         3    0.000    0.000    0.000    0.000 api.py:106(_get_distinct_objs)
#         3    0.000    0.000    0.000    0.000 api.py:120(_get_combined_index)
#         3    0.000    0.000    0.000    0.000 api.py:177(union_indexes)
#         3    0.000    0.000    0.000    0.000 api.py:229(<listcomp>)
#         3    0.000    0.000    0.000    0.000 api.py:230(<listcomp>)
#         3    0.000    0.000    0.000    0.000 api.py:275(_sanitize_and_check)
#         3    0.000    0.000    0.000    0.000 api.py:296(<setcomp>)
#         4    0.000    0.000    0.000    0.000 api.py:331(default_index)
#         3    0.000    0.000    0.000    0.000 api.py:76(get_objs_combined_axis)
#         9    0.000    0.000    0.018    0.002 array_ops.py:134(_na_arithmetic_op)
#         9    0.000    0.000    0.018    0.002 array_ops.py:183(arithmetic_op)
#         9    0.000    0.000    0.000    0.000 array_ops.py:441(maybe_prepare_scalar_for_op)
#         9    0.000    0.000    0.000    0.000 array_ops.py:510(_bool_arith_check)
#         7    0.000    0.000    0.016    0.002 arraylike.py:114(__mul__)
#         1    0.000    0.000    0.002    0.002 arraylike.py:118(__rmul__)
#         1    0.000    0.000    0.002    0.002 arraylike.py:122(__truediv__)
#         8    0.000    0.000    0.000    0.000 arraylike.py:180(_maybe_fallback)
#        16    0.000    0.000    0.000    0.000 arraylike.py:193(<genexpr>)
#        16    0.000    0.000    0.000    0.000 arraylike.py:194(<genexpr>)
#         8    0.063    0.008    0.065    0.008 arraylike.py:242(array_ufunc)
#        16    0.000    0.000    0.000    0.000 arraylike.py:284(<genexpr>)
#         8    0.000    0.000    0.000    0.000 arraylike.py:285(<listcomp>)
#         8    0.000    0.000    0.000    0.000 arraylike.py:317(<listcomp>)
#         8    0.000    0.000    0.001    0.000 arraylike.py:323(reconstruct)
#         8    0.000    0.000    0.001    0.000 arraylike.py:330(_reconstruct)
#        16    0.000    0.000    0.000    0.000 arraylike.py:396(<genexpr>)
#         8    0.000    0.000    0.000    0.000 arraylike.py:416(_standardize_out_kwarg)
#         9    0.000    0.000    0.020    0.002 base.py:1286(_arith_method)
#        49    0.000    0.000    0.000    0.000 base.py:1658(name)
#         3    0.000    0.000    0.000    0.000 base.py:1676(_validate_names)
#         6    0.000    0.000    0.000    0.000 base.py:1709(_get_names)
#         1    0.000    0.000    0.000    0.000 base.py:2240(is_unique)
#         8    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#         1    0.000    0.000    0.000    0.000 base.py:2352(is_floating)
#        11    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#         1    0.000    0.000    0.000    0.000 base.py:2604(inferred_type)
#         7    0.000    0.000    0.000    0.000 base.py:2632(_is_multi)
#         2    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:3047(_get_reconciled_name_object)
#         3    0.000    0.000    0.000    0.000 base.py:3058(_validate_sort_keyword)
#         3    0.000    0.000    0.000    0.000 base.py:3066(union)
#        40    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         3    0.000    0.000    0.000    0.000 base.py:3562(_assert_can_do_setop)
#         3    0.000    0.000    0.000    0.000 base.py:3568(_convert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 base.py:3585(get_loc)
#      12/8    0.000    0.000    0.001    0.000 base.py:397(__new__)
#         2    0.000    0.000    0.000    0.000 base.py:430(to_numpy)
#        23    0.000    0.000    0.001    0.000 base.py:4834(_values)
#         1    0.000    0.000    0.000    0.000 base.py:4860(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:4945(_validate_fill_value)
#        25    0.000    0.000    0.000    0.000 base.py:4987(__contains__)
#        11    0.000    0.000    0.000    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#         3    0.000    0.000    0.000    0.000 base.py:5106(append)
#         3    0.000    0.000    0.000    0.000 base.py:5131(<setcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:5136(_concat)
#         3    0.000    0.000    0.000    0.000 base.py:5140(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:518(<genexpr>)
#         8    0.000    0.000    0.003    0.000 base.py:5192(equals)
#        12    0.000    0.000    0.000    0.000 base.py:53(shape)
#         8    0.000    0.000    0.000    0.000 base.py:540(_ensure_array)
#        36    0.000    0.000    0.000    0.000 base.py:55(<genexpr>)
#         8    0.000    0.000    0.000    0.000 base.py:554(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:6298(_maybe_cast_indexer)
#         8    0.000    0.000    0.000    0.000 base.py:654(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6575(insert)
#         7    0.000    0.000    0.001    0.000 base.py:672(_with_infer)
#        25    0.000    0.000    0.001    0.000 base.py:7004(ensure_index)
#        29    0.000    0.000    0.000    0.000 base.py:7099(maybe_extract_name)
#         8    0.000    0.000    0.000    0.000 base.py:7123(_maybe_cast_data_without_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:794(_rename)
#         8    0.000    0.000    0.000    0.000 base.py:803(is_)
#        15    0.000    0.000    0.000    0.000 base.py:834(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:845(_engine)
#        68    0.000    0.000    0.000    0.000 base.py:884(__len__)
#         7    0.000    0.000    0.000    0.000 base.py:945(dtype)
#        21    0.000    0.000    0.000    0.000 blocks.py:1962(maybe_coerce_values)
#        22    0.000    0.000    0.000    0.000 blocks.py:1991(get_block_type)
#         4    0.000    0.000    0.000    0.000 blocks.py:2032(new_block_2d)
#        17    0.000    0.000    0.000    0.000 blocks.py:2043(new_block)
#        17    0.000    0.000    0.000    0.000 blocks.py:2057(check_ndim)
#         1    0.000    0.000    0.000    0.000 blocks.py:2137(ensure_block_shape)
#        24    0.000    0.000    0.000    0.000 blocks.py:244(mgr_locs)
#         8    0.000    0.000    0.000    0.000 blocks.py:267(make_block_same_class)
#         8    0.000    0.000    0.000    0.000 blocks.py:350(shape)
#         2    0.000    0.000    0.000    0.000 blocks.py:354(dtype)
#        19    0.000    0.000    0.000    0.000 cast.py:1711(sanitize_to_nanoseconds)
#         4    0.000    0.000    0.000    0.000 cast.py:1962(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 cast.py:2149(can_hold_element)
#         1    0.000    0.000    0.000    0.000 cast.py:2187(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 common.py:1091(is_datetimelike_v_numeric)
#         4    0.000    0.000    0.000    0.000 common.py:1148(needs_i8_conversion)
#        13    0.000    0.000    0.000    0.000 common.py:1240(is_float_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1274(is_bool_dtype)
#        26    0.000    0.000    0.000    0.000 common.py:1416(is_1d_only_ea_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#        33    0.000    0.000    0.000    0.000 common.py:145(classes)
#        33    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#        24    0.000    0.000    0.000    0.000 common.py:1483(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1496(is_complex_dtype)
#        16    0.000    0.000    0.000    0.000 common.py:150(classes_and_not_datetimelike)
#        16    0.000    0.000    0.000    0.000 common.py:155(<lambda>)
#         9    0.000    0.000    0.000    0.000 common.py:1552(get_dtype)
#        49    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 common.py:160(cast_scalar_indexer)
#        19    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#        46    0.000    0.000    0.000    0.000 common.py:1721(validate_all_hashable)
#        92    0.000    0.000    0.000    0.000 common.py:1740(<genexpr>)
#         6    0.000    0.000    0.000    0.000 common.py:1747(pandas_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:187(not_none)
#         9    0.000    0.000    0.000    0.000 common.py:191(<genexpr>)
#        12    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 common.py:287(maybe_iterable_to_list)
#        12    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 common.py:348(is_datetime64tz_dtype)
#         9    0.000    0.000    0.020    0.002 common.py:55(new_method)
#        19    0.000    0.000    0.000    0.000 common.py:552(require_length_match)
#         3    0.000    0.000    0.000    0.000 common.py:581(is_dtype_equal)
#         8    0.000    0.000    0.000    0.000 common.py:732(is_signed_integer_dtype)
#        15    0.000    0.000    0.000    0.000 common.py:75(get_op_result_name)
#         8    0.000    0.000    0.000    0.000 common.py:786(is_unsigned_integer_dtype)
#        13    0.000    0.000    0.000    0.000 common.py:97(_maybe_match_name)
#         3    0.000    0.000    0.000    0.000 concat.py:106(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:111(<setcomp>)
#         9    0.000    0.000    0.000    0.000 concat.py:112(<genexpr>)
#         3    0.000    0.000    0.000    0.000 concat.py:117(<setcomp>)
#         9    0.000    0.000    0.000    0.000 concat.py:118(<genexpr>)
#         3    0.000    0.000    0.033    0.011 concat.py:143(concat)
#         3    0.000    0.000    0.032    0.011 concat.py:185(concatenate_managers)
#         3    0.000    0.000    0.000    0.000 concat.py:208(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:255(_maybe_reindex_columns_na_proxy)
#         6    0.000    0.000    0.000    0.000 concat.py:287(_get_mgr_concatenation_plan)
#         8    0.000    0.000    0.000    0.000 concat.py:363(__init__)
#         3    0.000    0.000    0.001    0.000 concat.py:368(__init__)
#         3    0.000    0.000    0.000    0.000 concat.py:455(<listcomp>)
#         3    0.000    0.000    0.033    0.011 concat.py:544(get_result)
#         3    0.000    0.000    0.000    0.000 concat.py:604(_get_result_dim)
#         3    0.000    0.000    0.001    0.000 concat.py:610(_get_new_axes)
#         3    0.000    0.000    0.001    0.000 concat.py:612(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:617(_get_comb_axis)
#         3    0.000    0.000    0.000    0.000 concat.py:627(_get_concat_axis)
#         3    0.000    0.000    0.000    0.000 concat.py:661(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:678(_maybe_check_integrity)
#         3    0.000    0.000    0.000    0.000 concat.py:685(_concat_indexes)
#        11    0.000    0.000    0.000    0.000 concat.py:711(_combine_concat_plans)
#         3    0.000    0.000    0.000    0.000 concat.py:74(concat_compat)
#         6    0.000    0.000    0.000    0.000 concat.py:95(is_nonempty)
#        21    0.000    0.000    0.000    0.000 config.py:109(_get_single_key)
#        21    0.000    0.000    0.000    0.000 config.py:127(_get_option)
#        21    0.000    0.000    0.000    0.000 config.py:255(__call__)
#        21    0.000    0.000    0.000    0.000 config.py:571(_select_options)
#        21    0.000    0.000    0.000    0.000 config.py:589(_get_root)
#        42    0.000    0.000    0.000    0.000 config.py:603(_get_deprecated_option)
#        21    0.000    0.000    0.000    0.000 config.py:630(_translate_key)
#        21    0.000    0.000    0.000    0.000 config.py:642(_warn_if_deprecated)
#         1    0.000    0.000    0.002    0.002 construction.py:102(arrays_to_mgr)
#         4    0.000    0.000    0.000    0.000 construction.py:233(mgr_to_mgr)
#         3    0.000    0.000    0.001    0.000 construction.py:274(ndarray_to_mgr)
#        40    0.000    0.000    0.000    0.000 construction.py:379(extract_array)
#         3    0.000    0.000    0.000    0.000 construction.py:407(_check_values_indices_shape_match)
#         1    0.000    0.000    0.002    0.002 construction.py:425(dict_to_mgr)
#        42    0.000    0.000    0.000    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#        23    0.000    0.000    0.001    0.000 construction.py:470(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:483(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:486(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:494(<listcomp>)
#         3    0.000    0.000    0.000    0.000 construction.py:549(_prep_ndarray)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#        23    0.000    0.000    0.000    0.000 construction.py:630(_sanitize_ndim)
#         1    0.000    0.000    0.000    0.000 construction.py:635(_extract_index)
#        23    0.000    0.000    0.000    0.000 construction.py:667(_sanitize_str_dtypes)
#        23    0.000    0.000    0.000    0.000 construction.py:687(_maybe_repeat)
#        23    0.000    0.000    0.000    0.000 construction.py:698(_try_cast)
#         3    0.000    0.000    0.001    0.000 construction.py:747(_get_axes)
#        17    0.000    0.000    0.000    0.000 construction.py:805(is_empty_data)
#         1    0.032    0.032    0.629    0.629 data_analysis.py:268(get_transformed_data)
#         1    0.093    0.093    0.168    0.168 data_analysis.py:341(transform_coordinates_galactocentric)
#         1    0.136    0.136    0.321    0.321 data_analysis.py:396(transform_velocities_galactocentric)
#         1    0.018    0.018    0.067    0.067 data_analysis.py:450(transform_velocities_cylindrical)
#         9    0.000    0.000    0.000    0.000 dispatch.py:11(should_extension_dispatch)
#         7    0.000    0.000    0.000    0.000 enum.py:792(value)
#         9    0.000    0.000    0.018    0.002 expressions.py:223(evaluate)
#         9    0.000    0.000    0.018    0.002 expressions.py:63(_evaluate_standard)
#        24    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#        23    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#        20    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#         1    0.000    0.000    0.004    0.004 frame.py:10995(_reindex_for_setitem)
#         3    0.000    0.000    0.000    0.000 frame.py:1413(__len__)
#        11    0.000    0.000    0.000    0.000 frame.py:3463(__getitem__)
#         1    0.000    0.000    0.004    0.004 frame.py:3630(__setitem__)
#         1    0.000    0.000    0.000    0.000 frame.py:3797(_set_item_mgr)
#         1    0.000    0.000    0.004    0.004 frame.py:3822(_set_item)
#         1    0.000    0.000    0.000    0.000 frame.py:3883(_ensure_valid_index)
#        11    0.000    0.000    0.000    0.000 frame.py:3923(_get_item_cache)
#         1    0.000    0.000    0.004    0.004 frame.py:4518(_sanitize_column)
#         3    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#         7    0.000    0.000    0.003    0.000 frame.py:587(__init__)
#        12    0.000    0.000    0.000    0.000 frame.py:804(axes)
#         6    0.000    0.000    0.000    0.000 frame.py:821(shape)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:1474(_squeeze_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:1478(squeeze)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1751(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1755(ravel)
#         3    0.000    0.000    0.000    0.000 frozen.py:67(__getitem__)
#         1    0.000    0.000    0.000    0.000 function_base.py:5139(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5143(insert)
#         2    0.000    0.000    0.000    0.000 function_base.py:5333(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:5337(append)
#         8    0.000    0.000    0.065    0.008 generic.py:2097(__array_ufunc__)
#        24    0.000    0.000    0.000    0.000 generic.py:239(__init__)
#        23    0.000    0.000    0.000    0.000 generic.py:328(attrs)
#        43    0.000    0.000    0.000    0.000 generic.py:349(flags)
#         1    0.000    0.000    0.000    0.000 generic.py:3948(_check_setitem_copy)
#       300    0.000    0.000    0.000    0.000 generic.py:43(_check)
#        15    0.000    0.000    0.000    0.000 generic.py:546(_get_axis_number)
#        20    0.000    0.000    0.000    0.000 generic.py:5517(__finalize__)
#         6    0.000    0.000    0.000    0.000 generic.py:5549(<genexpr>)
#         9    0.000    0.000    0.000    0.000 generic.py:5554(<genexpr>)
#        40    0.000    0.000    0.000    0.000 generic.py:5561(__getattr__)
#        26    0.000    0.000    0.000    0.000 generic.py:5577(__setattr__)
#         6    0.000    0.000    0.000    0.000 generic.py:560(_get_axis)
#         6    0.000    0.000    0.000    0.000 generic.py:566(_get_block_manager_axis)
#        13    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#        12    0.000    0.000    0.000    0.000 generic.py:660(ndim)
#         1    0.000    0.000    0.000    0.000 indexing.py:2323(convert_to_index_sliceable)
#        11    0.000    0.000    0.000    0.000 indexing.py:2486(check_deprecated_indexers)
#        86    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#         2    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         6    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         6    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         6    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 managers.py:1229(insert)
#         6    0.000    0.000    0.000    0.000 managers.py:1267(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1277(_insert_update_mgr_locs)
#         1    0.000    0.000    0.000    0.000 managers.py:1287(_insert_update_blklocs_and_blknos)
#         3    0.000    0.000    0.000    0.000 managers.py:156(blknos)
#         4    0.000    0.000    0.000    0.000 managers.py:1675(is_consolidated)
#         4    0.000    0.000    0.000    0.000 managers.py:1683(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 managers.py:1693(_consolidate_inplace)
#        17    0.000    0.000    0.000    0.000 managers.py:1714(__init__)
#         3    0.000    0.000    0.000    0.000 managers.py:172(blklocs)
#        17    0.000    0.000    0.000    0.000 managers.py:1745(from_array)
#        17    0.000    0.000    0.000    0.000 managers.py:1806(_block)
#         2    0.000    0.000    0.000    0.000 managers.py:1851(dtype)
#        33    0.000    0.000    0.000    0.000 managers.py:1862(internal_values)
#         3    0.000    0.000    0.000    0.000 managers.py:1925(create_block_manager_from_blocks)
#         1    0.000    0.000    0.002    0.002 managers.py:1951(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:2006(_grouping_func)
#         1    0.000    0.000    0.002    0.002 managers.py:2022(_form_blocks)
#         1    0.002    0.002    0.002    0.002 managers.py:2074(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:2142(_fast_count_smallints)
#         6    0.000    0.000    0.000    0.000 managers.py:217(is_single_block)
#         4    0.000    0.000    0.000    0.000 managers.py:222(items)
#         7    0.000    0.000    0.000    0.000 managers.py:916(__init__)
#         3    0.000    0.000    0.000    0.000 managers.py:957(_verify_integrity)
#        11    0.000    0.000    0.000    0.000 managers.py:959(<genexpr>)
#         9    0.000    0.000    0.000    0.000 missing.py:138(dispatch_fill_zeros)
#         1    0.000    0.000    0.000    0.000 missing.py:150(_isna)
#         1    0.000    0.000    0.002    0.002 missing.py:391(array_equivalent)
#         1    0.000    0.000    0.000    0.000 missing.py:626(is_valid_na_for_dtype)
#         1    0.000    0.000    0.000    0.000 missing.py:67(isna)
#        16    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#         5    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:883(bincount)
#         2    0.000    0.000    0.000    0.000 numeric.py:1341(normalize_axis_tuple)
#         2    0.000    0.000    0.000    0.000 numeric.py:1391(<listcomp>)
#         1    0.000    0.000    0.000    0.000 numeric.py:1400(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:1404(moveaxis)
#         1    0.000    0.000    0.000    0.000 numeric.py:1466(<listcomp>)
#         1    0.000    0.000    0.001    0.001 numeric.py:149(ones)
#         1    0.000    0.000    0.000    0.000 numeric.py:2384(_array_equal_dispatcher)
#         1    0.002    0.002    0.002    0.002 numeric.py:2388(array_equal)
#        15    0.000    0.000    0.000    0.000 numeric.py:289(full)
#        17    0.000    0.000    0.000    0.000 numeric.py:331(_is_all_dates)
#         7    0.000    0.000    0.000    0.000 range.py:167(_simple_new)
#         1    0.000    0.000    0.001    0.001 range.py:189(_data)
#         1    0.000    0.000    0.000    0.000 range.py:241(start)
#         1    0.000    0.000    0.000    0.000 range.py:264(stop)
#         1    0.000    0.000    0.000    0.000 range.py:287(step)
#         7    0.000    0.000    0.000    0.000 range.py:347(dtype)
#         3    0.000    0.000    0.000    0.000 range.py:439(_view)
#         3    0.000    0.000    0.000    0.000 range.py:444(copy)
#         9    0.000    0.000    0.000    0.000 range.py:522(equals)
#        28    0.000    0.000    0.000    0.000 range.py:909(__len__)
#         7    0.000    0.000    0.000    0.000 re.py:250(compile)
#         7    0.000    0.000    0.000    0.000 re.py:289(_compile)
#         1    0.002    0.002    0.002    0.002 roperator.py:16(rmul)
#         9    0.000    0.000    0.001    0.000 series.py:2988(_construct_result)
#        17    0.000    0.000    0.002    0.000 series.py:323(__init__)
#        17    0.000    0.000    0.000    0.000 series.py:523(_constructor)
#        17    0.000    0.000    0.000    0.000 series.py:542(_set_axis)
#         9    0.000    0.000    0.020    0.002 series.py:5637(_arith_method)
#         2    0.000    0.000    0.000    0.000 series.py:575(dtype)
#       103    0.000    0.000    0.000    0.000 series.py:590(name)
#        43    0.000    0.000    0.000    0.000 series.py:640(name)
#        33    0.000    0.000    0.000    0.000 series.py:687(_values)
#         6    0.000    0.000    0.000    0.000 series.py:825(__array__)
#         8    0.000    0.000    0.000    0.000 series.py:885(axes)
#         2    0.000    0.000    0.000    0.000 socket.py:543(send)
#         2    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 threading.py:1126(is_alive)
#         2    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         1    0.035    0.035    0.049    0.049 transformation_constants.py:112(get_cylindrical_velocity_matrix)
#         2    0.000    0.000    0.000    0.000 transformation_constants.py:55(get_H_matrix)
#         1    0.158    0.158    0.168    0.168 transformation_constants.py:79(get_b_matrix)
#         7    0.000    0.000    0.000    0.000 types.py:171(__get__)
#        48    0.000    0.000    0.000    0.000 typing.py:1375(cast)
#         7    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         7    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         7    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         7    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         7    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#        15    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55f434a54740}
#         7    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         7    0.014    0.002    0.014    0.002 {built-in method _operator.mul}
#         1    0.002    0.002    0.002    0.002 {built-in method _operator.truediv}
#        21    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.630    0.630 {built-in method builtins.exec}
#       401    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       114    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       111    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#      1352    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       119    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#   486/387    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.001    0.001    0.001    0.001 {built-in method numpy.arange}
#        12    0.015    0.001    0.015    0.001 {built-in method numpy.array}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        37    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#     34/29    0.001    0.000    0.003    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        22    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        18    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         5    0.014    0.003    0.014    0.003 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         7    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.is_matching_na}
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         3    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x7fa8fcefdca0}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'add' of 'pandas._libs.internals.BlockPlacement' objects}
#        12    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        35    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         9    0.033    0.004    0.033    0.004 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         8    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         7    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        15    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        64    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        14    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        21    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        15    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}

# %% [markdown]
# # Covariance Transformation

# %% [markdown]
# ## Covariance Transformation Prototype

# %%
from transformation_constants import A, k1, k2

A = cp.asarray(A, dtype=cp.float32)

def get_jacobian_bayes_gpu(df, coordinate_system, Z_0, R_0):

    n = len(df)
    
    if(coordinate_system == "Cartesian"):

        if(Z_0/R_0 is None):
                print("Something went wrong! No values for either Z_0 or R_0 were found!")
                return
    
        THETA_0 = cp.arcsin(Z_0/R_0, dtype = cp.float32)

        # TODO: Implement exception handling!

        # DF -> ["ra", "dec","r_est","pmra","pmdec","radial_velocity"]
        r_est = df[:,2]

        c1 = r_est
        c2 = cp.float32(1)
        c3 = k2*(r_est/1000)
        c4 = -k2/1000

        ra = df[:,0]
        dec = df[:,1]
        mu_ra = df[:,3]
        mu_dec = df[:,4]
        v_r = df[:,5]

        # deg -> radians
        ra = cp.deg2rad(ra)
        dec = cp.deg2rad(dec)

        # Declaring variables to reduce number of computations 
        sin_ra = cp.sin(ra)
        cos_ra = cp.cos(ra)
        sin_dec = cp.sin(dec)
        cos_dec = cp.cos(dec)
        sin_theta = cp.sin(THETA_0)
        cos_theta = cp.cos(THETA_0)
        
        A_1 = A[0,0]*cos_theta + A[2,0]*sin_theta
        A_2 = A[0,1]*cos_theta + A[2,1]*sin_theta
        A_3 = A[0,2]*cos_theta + A[2,2]*sin_theta
        A_4 = -A[1,0]*sin_ra + A[1,1]*cos_ra
        A_5 = A[1,0]*cos_ra + A[1,1]*sin_ra
        A_6 = A[2,2]*cos_theta - A[0,2]*sin_theta
        A_7 = A[2,0]*cos_theta - A[0,0]*sin_theta
        A_8 = A[2,1]*cos_theta - A[0,1]*sin_theta
        
        print(THETA_0.dtype)
        cosra_cosdec = cos_ra*cos_dec
        cosra_sindec = cos_ra*sin_dec
        sinra_cosdec = sin_ra*cos_dec
        sinra_sindec = sin_ra*sin_dec

        expr_1 = cos_dec*v_r - sin_dec*c3*mu_dec
        #expr_2 = -cos_dec*v_r + sin_dec*c3*mu_dec
        expr_3 = -sin_dec*v_r - cos_dec*c3*mu_dec
        expr_4 = sin_ra*c4*mu_ra + cosra_sindec*c4*mu_dec
        #expr_5 = cos_ra*c3*mu_ra
        #expr_6 = sin_ra*c3*mu_ra
        expr_7 = -cos_ra*c4*mu_ra + sinra_sindec*c4*mu_dec
        expr_8 = -sin_ra*v_r + c3*(cos_dec**(-1))*(-cos_ra*mu_ra + sinra_sindec*mu_dec)
        expr_9 = cos_ra*v_r - c3*(cos_dec**(-1))*(sin_ra*mu_ra + cosra_sindec*mu_dec)

        

        J11 = c1*(-sin_ra*(A_1) + cos_ra*(A_2))
        J12 = c1*(cos_dec*(A_3) - sin_dec*(cos_ra*(A_1) + sin_ra*(A_2)))
        J13 = c2*(cosra_cosdec*(A_1) + sinra_cosdec*(A_2) + sin_dec*(A_3))
        J14 = cp.zeros(n, dtype=cp.float32)
        #J15 = np.zeros(n)
        #J16 = np.zeros(n)
        
        #row_1 = np.array([J11, J12, J13, J14, J15, J16])
        
        J21 = c1*(A_4) 
        J22 = c1*(-sin_dec*A_5 + A[1,2]*cos_dec) 
        J23 = c2*(cos_dec*A_5 + A[1,2]*sin_dec)
        # J24 = np.zeros(n)
        # J25 = np.zeros(n)
        # J26 = np.zeros(n)

        #J31 = c1*(-sin_theta*(A[0,1]*cos_ra - A[0,0]*sin_ra) + cos_theta*(A[2,1]*cos_ra - A[2,0]*sin_ra))
        J31 = c1*(-sin_ra*(A_7) + cos_ra*(A_8))
        J32 = -c1*(sin_dec*(cos_ra*(A[0,0]*sin_theta - A[2,0]*cos_theta) + sin_ra*(A[0,1]*sin_theta - A[2,1]*cos_theta)) + cos_dec*(A_6))
        J33 = c2*(cosra_cosdec*(A_7) + sinra_cosdec*(A_8) + sin_dec*(A_6))     
        # J34 = np.zeros(n)
        # J35 = np.zeros(n)
        # J36 = np.zeros(n)

        #J41 = (sin_ra*(expr_2) - expr_5)*(A_1) + (cos_ra*(expr_1) - expr_6)*(A_2)

        J41 = (expr_8)*(A_1) + (expr_9)*(A_2)
        J42 = cos_ra*(expr_3)*(A_1) + sin_ra*(expr_3)*(A_2) + (expr_1)*(A_3)
        J43 = (expr_4)*(A_1) + (expr_7)*(A_2) + (-cos_dec*c4*mu_dec)*(A_3)
        J44 = -sin_ra*c3*(A_1) + cos_ra*c3*(A_2)
        J45 = (-cosra_sindec*c3)*(A_1) + (-sinra_sindec*c3)*(A_2) + (cos_dec*c3)*(A_3)
        J46 = cosra_cosdec*(A_1) + sinra_cosdec*(A_2) + sin_dec*(A_3)

        #J51 = A[1,0]*(-sinra_cosdec*v_r - expr_5 + sinra_sindec*c3*mu_dec) + A[1,1]*(cosra_cosdec*v_r - expr_6- cosra_sindec*c3*mu_dec)
        J51 = A[1,0]*(expr_8) + A[1,1]*(expr_9)
        J52 = A[1,0]*cos_ra*(expr_3) + A[1,1]*sin_ra*(expr_3) + A[1,2]*(expr_1)
        J53 = A[1,0]*(expr_4) + A[1,1]*(expr_7) + A[1,2]*(-cos_dec*c4*mu_dec)
        J54 = c3*(A_4)
        J55 = c3*(-A[1,0]*cosra_sindec- A[1,1]*sinra_sindec + A[1,2]*cos_dec)
        J56 = (A[1,0]*cos_ra + A[1,1]*sin_ra)*cos_dec + A[1,2]*sin_dec

        #J61 = (sin_ra*(expr_2) - expr_5)*(A_7) + (cos_ra*(expr_1) - expr_6)*(A_8)
        J61 = (expr_8)*(A_7) + (expr_9)*(A_8)
        J62 = cos_ra*(expr_3)*(A_7) + sin_ra*(expr_3)*(A_8) + (expr_1)*(A_6)
        J63 = c4*((sin_ra*mu_ra + cosra_sindec*mu_dec)*(A_7) + (-cos_ra*mu_ra + sinra_sindec*mu_dec)*(A_8) - cos_dec*mu_dec*(A_6))
        J64 = c3*(-sin_ra*(A_7) + cos_ra*(A_8))
        J65 = c3*(-cosra_sindec*(A_7) - sinra_sindec*(A_8) + cos_dec*(A_6))
        J66 = cosra_cosdec*(A_7) + sinra_cosdec*(A_8) + sin_dec*(A_6)
        
        

        J1 = cp.stack((J11, J12, J13, J14, J14, J14))
        J2 = cp.stack((J21, J22, J23, J14, J14, J14))
        J3 = cp.stack((J31, J32, J33, J14, J14, J14))
        J4 = cp.stack((J41, J42, J43, J44, J45, J46))
        J5 = cp.stack((J51, J52, J53, J54, J55, J56))
        J6 = cp.stack((J61, J62, J63, J64, J65, J66))
        
        J = cp.stack((J1, J2, J3, J4, J5, J6))
       
    return J


def get_jacobian_gpu(df, coordinate_system, Z_0, R_0):

    n = len(df)
    
    if(coordinate_system == "Cylindrical"):

        # TODO: Implement exception handling!

        # DF -> ["x", "y","r","phi","v_r","v_phi"]

        x = df[:,0]
        y = df[:,1]
        r = df[:,2]
        phi = df[:,3]
        v_r = df[:,4]
        v_phi = df[:,5]


    
        c1 = x/(r**2)
        c2 = y/(r**2)
        
        # Declaring variables to reduce number of computations 
        sin_phi = cp.sin(phi)
        cos_phi = cp.cos(phi)

        J11 = x/r
        J12 = y/r
        J13 = cp.zeros(n, dtype=cp.float32)
        #J14 = np.zeros(n)
        #J15 = np.zeros(n)
        #J16 = np.zeros(n)
    
        J21 = -c2 
        J22 = c1
        #J23 = np.zeros(n)
        #J24 = np.zeros(n)
        #J25 = np.zeros(n)
        #J26 = np.zeros(n)

        #J31 = np.zeros(n)
        #J32 = np.zeros(n)
        J33 = cp.ones(n, dtype=cp.float32)
        #J34 = np.zeros(n)
        #J35 = np.zeros(n)
        #J36 = np.zeros(n)

        J41 = -v_phi*c2
        J42 = v_phi*c1
        #J43 = np.zeros(n)
        J44 = cos_phi
        J45 = sin_phi
        #J46 = np.zeros(n)

        J51 = v_r*c2
        J52 = -v_r*c1
        #J53 = np.zeros(n) 
        J54 = -sin_phi
        J55 = cos_phi
        #J56 = np.zeros(n)

        #J61 = np.zeros(n)
        #J62 = np.zeros(n)
        #J63 = np.zeros(n)
        #J64 = np.zeros(n)
        #J65 = np.zeros(n)
        #J66 = np.ones(n)
               
        J1 = cp.stack((J11, J12, J13, J13, J13, J13))
        J2 = cp.stack((J21, J22, J13, J13, J13, J13))
        J3 = cp.stack((J13, J13, J33, J13, J13, J13))
        J4 = cp.stack((J41, J42, J13, J44, J45, J13))
        J5 = cp.stack((J51, J52, J13, J54, J55, J13))
        J6 = cp.stack((J13, J13, J13, J13, J13, J33))
        
        J = cp.stack((J1, J2, J3, J4, J5, J6))
        
    return J


def transform_cov_matrix_gpu(C, 
                        df, 
                        coordinate_system, 
                        z_0 = transformation_constants.Z_0, 
                        r_0 = transformation_constants.R_0, 
                        is_bayes = False):
    """Transforms an array of covariance matrices to specified coordinate system.

    Args:
        C (Array): Arrays of covariance matrices
        df (DataFrame): DataFrame of Gaia data used for generating Jacobian matrices for each observation.
        coordinate_system (str): Specified coordinate system, either "Cartesian" or "Cylindrical".
        z_0 (float, optional): Sun's height over Galactic plane. Defaults to transformation_constants.Z_0.
        r_0 (float, optional): Sun's distance from Galactic centre. Defaults to transformation_constants.R_0.
        is_bayes (bool, optional): Set True if using distance estimates instead of parallaxes. Defaults to False.

    Returns:
        Array: Returns array of transformed covariance matrices.
    """

    if(is_bayes == True):
        # Grabs the correct Jacobian for every point in data set. Of shape (n, 6, 6).
        J = get_jacobian_bayes_gpu(df, 
                                coordinate_system, 
                                Z_0 = z_0, 
                                R_0 = r_0)
        print(J.dtype)

    else:
        # Grabs the correct Jacobian for every point in data set. Of shape (n, 6, 6).
        J = get_jacobian_gpu(df, 
                            coordinate_system, 
                            Z_0 = z_0, 
                            R_0 = r_0)


    J = J.T.reshape(len(df), 6, 6, order = 'A').swapaxes(1,2)
    J_trunc= J.reshape(len(df),6,6, order = 'A').swapaxes(1,2)

    C_transformed_gpu = cp.matmul(cp.matmul(J, C), J_trunc)

    return C_transformed_gpu

# %%
def transform_cov_matrix(C, 
                        df, 
                        coordinate_system, 
                        z_0 = transformation_constants.Z_0, 
                        r_0 = transformation_constants.R_0, 
                        is_bayes = False):
    """Transforms an array of covariance matrices to specified coordinate system.

    Args:
        C (Array): Arrays of covariance matrices
        df (DataFrame): DataFrame of Gaia data used for generating Jacobian matrices for each observation.
        coordinate_system (str): Specified coordinate system, either "Cartesian" or "Cylindrical".
        z_0 (float, optional): Sun's height over Galactic plane. Defaults to transformation_constants.Z_0.
        r_0 (float, optional): Sun's distance from Galactic centre. Defaults to transformation_constants.R_0.
        is_bayes (bool, optional): Set True if using distance estimates instead of parallaxes. Defaults to False.

    Returns:
        Array: Returns array of transformed covariance matrices.
    """

    if(is_bayes == True):
        # Grabs the correct Jacobian for every point in data set. Of shape (n, 6, 6).
        J = transformation_constants.get_jacobian_bayes(df, 
                                                        coordinate_system, 
                                                        Z_0 = z_0, 
                                                        R_0 = r_0)
    else:
        # Grabs the correct Jacobian for every point in data set. Of shape (n, 6, 6).
        J = transformation_constants.get_jacobian(df, 
                                                coordinate_system, 
                                                Z_0 = z_0, 
                                                R_0 = r_0)

    J = J.T.reshape(len(df), 6, 6, order = 'A').swapaxes(1,2)

    J_trunc= J.reshape(len(df),6,6, order = 'A').swapaxes(1,2)

    C_transformed = J @ C @ J_trunc

    return C_transformed

# %% [markdown]
# ## Testing Covariance Transformation
# ### Galactocentric Covariance Transformation

# %%
# Gets columns after 'source_id'
# ["ra", "dec","r_est","pmra","pmdec","radial_velocity"]
data_array = icrs_gpu[:,1::]
data_array.dtype

galactocentric_cov = transform_cov_matrix_gpu(C_icrs_gpu, 
                                        data_array, 
                                        "Cartesian", 
                                        z_0=z_0, 
                                        r_0=r_0, 
                                        is_bayes=True)
galactocentric_cov.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 6
#       3 data_array = icrs_gpu[:,1::]
#       4 data_array.dtype
# ----> 6 galactocentric_cov = transform_cov_matrix_gpu(C_icrs_gpu,
#       7                                         data_array,
#       8                                         "Cartesian",
#       9                                         z_0=z_0,
#      10                                         r_0=r_0,
#      11                                         is_bayes=True)
#      12 galactocentric_cov.dtype
#
# NameError: name 'transform_cov_matrix_gpu' is not defined

# %% [markdown]
# ### Cylindrical Covariance Transformation

# %%
# Gets correct columns for next transformation
#["x", "y","r","phi","v_r","v_phi"]
data_array_galcen = galcen_gpu[:,[0,1,6,7,8,9]]

cyl_cov_gpu = transform_cov_matrix_gpu(galactocentric_cov, 
                                        data_array_galcen, 
                                        "Cylindrical", 
                                        z_0=z_0, 
                                        r_0=r_0)
cyl_cov_gpu.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 3
#       1 # Gets coorect columns for next transformation
#       2 #["x", "y","r","phi","v_r","v_phi"]
# ----> 3 data_array_galcen = galcen_gpu[:,[0,1,6,7,8,9]]
#       5 cyl_cov_gpu = transform_cov_matrix_gpu(galactocentric_cov,
#       6                                         data_array_galcen,
#       7                                         "Cylindrical",
#       8                                         z_0=z_0,
#       9                                         r_0=r_0)
#      10 cyl_cov_gpu.dtype
#
# NameError: name 'galcen_gpu' is not defined

# %%
# Generate covariance matrix in ICRS
C_icrs = cov.generate_covmat(icrs_data)
C_icrs_gpu = cp.asarray(C_icrs, dtype=cp.float32)

trans_needed_columns = ['source_id', 'ra', 'dec', 'r_est', 'pmra', 'pmdec', 'radial_velocity']

icrs_cpu = icrs_data[trans_needed_columns].to_numpy()
icrs_gpu = cp.asarray(icrs_data[trans_needed_columns], dtype=cp.float32)

data_array_cpu = icrs_cpu[:,1::]
data_array_gpu = icrs_gpu[:,1::]

data_array_galcen_cpu = galcen_data_new_cpu[:,[0,1,6,7,8,9]]
data_array_galcen_gpu = galcen_data_new_gpu[:,[0,1,6,7,8,9]]

# Old function
galactocentric_cov = cov.transform_cov_galactocentric(df = icrs_data, 
                                                        C = C_icrs,
                                                        is_bayes = True,
                                                        Z_0 = z_0,
                                                        R_0 = r_0)

cyl_cov = cov.transform_cov_cylindirical(df_crt = galcen_data, 
                                        C = galactocentric_cov,
                                        Z_0 = z_0,
                                        R_0 = r_0)

# CPU TESTING SECTION -------------------------------------------------------->
# New function
NUMPY_LIB = np
galactocentric_cov_cpu = cov.transform_cov_matrix(C = C_icrs, 
                                                df = data_array_cpu,
                                                coordinate_system = 'Cartesian',
                                                z_0 = z_0,
                                                r_0 = r_0,
                                                is_bayes = True,
                                                NUMPY_LIB = NUMPY_LIB)

cyl_cov_cpu = cov.transform_cov_matrix(C = galactocentric_cov_cpu, 
                                    df = data_array_galcen_cpu,
                                    coordinate_system = 'Cylindrical',
                                    z_0 = z_0,
                                    r_0 = r_0,
                                    is_bayes = False,
                                    NUMPY_LIB = NUMPY_LIB)


# GPU TESTING SECTION -------------------------------------------------------->
NUMPY_LIB = cp
dtype = cp.float32
galactocentric_cov_gpu = cov.transform_cov_matrix(C = C_icrs_gpu, 
                                                df = data_array_gpu,
                                                coordinate_system = 'Cartesian',
                                                z_0 = z_0,
                                                r_0 = r_0,
                                                is_bayes = True,
                                                NUMPY_LIB = NUMPY_LIB,
                                                dtype = dtype)

cyl_cov_gpu = cov.transform_cov_matrix(C = galactocentric_cov_gpu, 
                                    df = data_array_galcen_gpu,
                                    coordinate_system = 'Cylindrical',
                                    z_0 = z_0,
                                    r_0 = r_0,
                                    is_bayes = False,
                                    NUMPY_LIB = NUMPY_LIB,
                                    dtype = dtype)

# %%
print(cyl_cov.iloc[0].sig_vphi)
print(cyl_cov_cpu[0, 4, 4])
print(cyl_cov_gpu[0, 4, 4])

print(cyl_cov.shape)
print(cyl_cov_cpu.shape)
print(cyl_cov_gpu.shape)

print(cyl_cov.dtypes)
print(cyl_cov_cpu.dtype)
print(cyl_cov_gpu.dtype)
# Out:
# 0.007613203980363394
# 0.007613203980363394
# 0.0076132035
# (100, 3)
# (100, 6, 6)
# (100, 6, 6)
# source_id      int64
# sig_vphi     float64
# sig_vr       float64
# dtype: object
# float64
# float32

# %%
final_columns = ['x', 'y', 'z', 'v_x', 'v_y', 'v_z', 'r', 'phi', 'v_r', 'v_phi',
       'sig_vphi', 'sig_vr', 'source_id']

# %%
sig_vphi = cp.array([cyl_cov_gpu[:,4,4]])
sig_vr = cp.array([cyl_cov_gpu[:,3,3]])
source_id = cp.array([icrs_gpu[:,0]])
df_test = cp.concatenate(([galcen_data_new_gpu, sig_vphi.T, sig_vr.T, source_id.T]), axis=1)


# OUTSIDE FUNC
pandas_frame = pd.DataFrame(df_test.get(), columns=final_columns)
pandas_frame.shape
# Out:
# (1000000, 13)

# %% [markdown]
# ## Profiling Covariance Transformation

# %%
def cov_func_gpu():
    galactocentric_cov_gpu = cov.transform_cov_matrix(C = C_icrs_gpu, 
                                                df = data_array_gpu,
                                                coordinate_system = 'Cartesian',
                                                z_0 = z_0,
                                                r_0 = r_0,
                                                is_bayes = True,
                                                NUMPY_LIB = NUMPY_LIB,
                                                dtype = dtype)

    cyl_cov_gpu = cov.transform_cov_matrix(C = galactocentric_cov_gpu, 
                                    df = data_array_galcen_gpu,
                                    coordinate_system = 'Cylindrical',
                                    z_0 = z_0,
                                    r_0 = r_0,
                                    is_bayes = False,
                                    NUMPY_LIB = NUMPY_LIB,
                                    dtype = dtype)

# %%
def cov_func():

    # Old function
    galactocentric_cov = cov.transform_cov_galactocentric(df = icrs_data, 
                                                            C = C_icrs,
                                                            is_bayes = True,
                                                            Z_0 = z_0,
                                                            R_0 = r_0)

    cyl_cov = cov.transform_cov_cylindirical(df_crt = galcen_data, 
                                            C = galactocentric_cov,
                                            Z_0 = z_0,
                                            R_0 = r_0)

# %%
cProfile.run('cov_func_gpu()')
# Out:
#          1434 function calls in 0.011 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.011    0.011 1581584888.py:1(cov_func_gpu)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(can_cast)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(min_scalar_type)
#         1    0.000    0.000    0.011    0.011 <string>:1(<module>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:194(_determine_from_args)
#        12    0.000    0.000    0.000    0.000 _gufuncs.py:196(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:253(determine_dtype)
#         4    0.000    0.000    0.001    0.000 _gufuncs.py:390(_apply_func_to_inputs)
#         8    0.000    0.000    0.000    0.000 _gufuncs.py:416(_transpose_element)
#        24    0.000    0.000    0.000    0.000 _gufuncs.py:417(<genexpr>)
#        16    0.000    0.000    0.000    0.000 _gufuncs.py:419(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:424(_get_args_transposed)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:46(_validate_normalize_axes)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:473(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:474(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:478(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:479(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:484(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:493(<listcomp>)
#        16    0.000    0.000    0.000    0.000 _gufuncs.py:494(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:500(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:523(_determine_order)
#         4    0.000    0.000    0.002    0.000 _gufuncs.py:541(__call__)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:65(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:665(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:667(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:93(<listcomp>)
#         4    0.000    0.000    0.000    0.000 _gufuncs.py:95(<listcomp>)
#         8    0.000    0.000    0.000    0.000 _internal.py:250(__init__)
#         8    0.000    0.000    0.000    0.000 _internal.py:304(data)
#        84    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 basic.py:138(ones)
#         2    0.000    0.000    0.000    0.000 basic.py:196(zeros)
#         4    0.000    0.000    0.000    0.000 basic.py:7(empty)
#         2    0.000    0.000    0.011    0.005 covariance_generation.py:224(transform_cov_matrix)
#        84    0.000    0.000    0.001    0.000 dims.py:132(expand_dims)
#         2    0.000    0.000    0.001    0.000 from_data.py:49(asarray)
#        14    0.000    0.000    0.003    0.000 join.py:122(stack)
#        14    0.000    0.000    0.001    0.000 join.py:135(<listcomp>)
#        14    0.000    0.000    0.002    0.000 join.py:35(concatenate)
#         4    0.000    0.000    0.000    0.000 multiarray.py:498(can_cast)
#        16    0.000    0.000    0.000    0.000 multiarray.py:613(min_scalar_type)
#       168    0.000    0.000    0.000    0.000 numeric.py:1859(isscalar)
#         1    0.005    0.005    0.007    0.007 transformation_constants.py:128(get_jacobian_bayes)
#         1    0.000    0.000    0.002    0.002 transformation_constants.py:262(get_jacobian)
#         2    0.000    0.000    0.001    0.000 transformation_constants.py:46(get_A_matrix)
#        84    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.011    0.011 {built-in method builtins.exec}
#       268    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       154    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.001    0.000    0.001    0.000 {built-in method cupy._core._routines_linalg.matmul}
#        84    0.000    0.000    0.001    0.000 {built-in method cupy._core._routines_manipulation._expand_dims}
#         8    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation.broadcast_to}
#        14    0.002    0.000    0.002    0.000 {built-in method cupy._core._routines_manipulation.concatenate_method}
#         2    0.001    0.000    0.001    0.000 {built-in method cupy._core.core.array}
#         4    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._broadcast_shapes}
#         4    0.000    0.000    0.000    0.000 {built-in method cupy._core.internal._get_strides_for_order_K}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#         4    0.000    0.000    0.000    0.000 {method '_set_shape_and_strides' of 'cupy._core.core._ndarray_base' objects}
#        36    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fill' of 'cupy._core.core._ndarray_base' objects}
#        24    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'memset_async' of 'cupy.cuda.memory.MemoryPointer' objects}
#        32    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'cupy._core.core._ndarray_base' objects}
#         4    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'cupy._core.core._ndarray_base' objects}
#        12    0.000    0.000    0.000    0.000 {method 'transpose' of 'cupy._core.core._ndarray_base' objects}
#        16    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}

# %%
cProfile.run('cov_func()')
# Out:
#          2398 function calls (2365 primitive calls) in 1.937 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    1.936    1.936 2532643863.py:1(cov_func)
#        14    0.000    0.000    0.209    0.015 <__array_function__ internals>:177(concatenate)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#        14    0.000    0.000    0.209    0.015 <__array_function__ internals>:177(stack)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         1    0.001    0.001    1.937    1.937 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 _asarray.py:111(<setcomp>)
#         2    0.000    0.000    0.000    0.000 _asarray.py:22(require)
#         4    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         4    0.000    0.000    0.000    0.000 _dtype.py:314(_name_includes_bit_suffix)
#         4    0.000    0.000    0.000    0.000 _dtype.py:328(_name_get)
#         2    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#         2    0.000    0.000    0.000    0.000 _methods.py:46(_sum)
#         4    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         6    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 algorithms.py:1356(take)
#         1    0.000    0.000    0.000    0.000 api.py:177(union_indexes)
#         4    0.000    0.000    0.000    0.000 base.py:1106(take)
#         4    0.000    0.000    0.000    0.000 base.py:1132(_maybe_disallow_fill)
#         8    0.000    0.000    0.000    0.000 base.py:1658(name)
#         2    0.000    0.000    0.000    0.000 base.py:1906(nlevels)
#         8    0.000    0.000    0.000    0.000 base.py:2280(is_boolean)
#         5    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#         1    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#         4    0.000    0.000    0.000    0.000 base.py:2604(inferred_type)
#         4    0.000    0.000    0.000    0.000 base.py:2632(_is_multi)
#        23    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         4    0.000    0.000    0.001    0.000 base.py:3714(get_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:3794(_get_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:3837(_check_indexing_method)
#       6/5    0.000    0.000    0.001    0.000 base.py:397(__new__)
#         2    0.000    0.000    0.000    0.000 base.py:4123(reindex)
#         2    0.000    0.000    0.000    0.000 base.py:4240(_wrap_reindex_result)
#         2    0.000    0.000    0.000    0.000 base.py:4244(_maybe_preserve_names)
#        44    0.000    0.000    0.000    0.000 base.py:4834(_values)
#         4    0.000    0.000    0.000    0.000 base.py:4860(_get_engine_target)
#         2    0.000    0.000    0.000    0.000 base.py:4987(__contains__)
#         1    0.000    0.000    0.000    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#         2    0.000    0.000    0.000    0.000 base.py:518(<genexpr>)
#         8    0.000    0.000    0.000    0.000 base.py:5192(equals)
#         4    0.000    0.000    0.000    0.000 base.py:53(shape)
#         5    0.000    0.000    0.000    0.000 base.py:540(_ensure_array)
#        12    0.000    0.000    0.000    0.000 base.py:55(<genexpr>)
#         5    0.000    0.000    0.000    0.000 base.py:554(_dtype_to_subclass)
#         2    0.000    0.000    0.001    0.000 base.py:5758(get_indexer_for)
#         2    0.000    0.000    0.001    0.001 base.py:5782(_get_indexer_strict)
#         2    0.000    0.000    0.000    0.000 base.py:5813(_raise_if_missing)
#        10    0.000    0.000    0.000    0.000 base.py:5919(_index_as_unique)
#         4    0.000    0.000    0.000    0.000 base.py:5931(_maybe_promote)
#         4    0.000    0.000    0.000    0.000 base.py:6018(_should_compare)
#         4    0.000    0.000    0.000    0.000 base.py:6036(_is_comparable_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:6307(_maybe_cast_listlike_indexer)
#         9    0.000    0.000    0.000    0.000 base.py:654(_simple_new)
#         4    0.000    0.000    0.001    0.000 base.py:672(_with_infer)
#         8    0.000    0.000    0.001    0.000 base.py:7004(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:7063(ensure_has_len)
#         6    0.000    0.000    0.000    0.000 base.py:7099(maybe_extract_name)
#         5    0.000    0.000    0.000    0.000 base.py:7123(_maybe_cast_data_without_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:7185(unpack_nested_dtype)
#         8    0.000    0.000    0.000    0.000 base.py:803(is_)
#         9    0.000    0.000    0.000    0.000 base.py:834(_reset_identity)
#        13    0.000    0.000    0.000    0.000 base.py:884(__len__)
#         8    0.000    0.000    0.000    0.000 base.py:945(dtype)
#         2    0.000    0.000    0.022    0.011 blocks.py:1116(take_nd)
#         2    0.000    0.000    0.000    0.000 blocks.py:1991(get_block_type)
#         2    0.000    0.000    0.000    0.000 blocks.py:222(get_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:267(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 blocks.py:354(dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:1711(sanitize_to_nanoseconds)
#         1    0.000    0.000    0.000    0.000 cast.py:1962(construct_1d_object_array_from_listlike)
#         4    0.000    0.000    0.000    0.000 cast.py:468(maybe_promote)
#         2    0.000    0.000    0.000    0.000 common.py:105(is_bool_indexer)
#         6    0.000    0.000    0.000    0.000 common.py:1240(is_float_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:1416(is_1d_only_ea_dtype)
#         8    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#        28    0.000    0.000    0.000    0.000 common.py:145(classes)
#        28    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#        12    0.000    0.000    0.000    0.000 common.py:1483(is_ea_or_datetimelike_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:150(classes_and_not_datetimelike)
#        10    0.000    0.000    0.000    0.000 common.py:155(<lambda>)
#        20    0.000    0.000    0.000    0.000 common.py:1552(get_dtype)
#        38    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#        22    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1747(pandas_dtype)
#         8    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#         3    0.000    0.000    0.000    0.000 common.py:287(maybe_iterable_to_list)
#         3    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#         3    0.000    0.000    0.000    0.000 common.py:348(is_datetime64tz_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:459(is_interval_dtype)
#        16    0.000    0.000    0.000    0.000 common.py:497(is_categorical_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:552(require_length_match)
#        10    0.000    0.000    0.000    0.000 common.py:581(is_dtype_equal)
#         5    0.000    0.000    0.000    0.000 common.py:732(is_signed_integer_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:786(is_unsigned_integer_dtype)
#         1    0.000    0.000    0.000    0.000 config.py:109(_get_single_key)
#         1    0.000    0.000    0.000    0.000 config.py:127(_get_option)
#         1    0.000    0.000    0.000    0.000 config.py:255(__call__)
#         1    0.000    0.000    0.000    0.000 config.py:571(_select_options)
#         1    0.000    0.000    0.000    0.000 config.py:589(_get_root)
#         2    0.000    0.000    0.000    0.000 config.py:603(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 config.py:630(_translate_key)
#         1    0.000    0.000    0.000    0.000 config.py:642(_warn_if_deprecated)
#         1    0.000    0.000    0.018    0.018 construction.py:102(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 construction.py:233(mgr_to_mgr)
#         3    0.000    0.000    0.000    0.000 construction.py:379(extract_array)
#         1    0.000    0.000    0.018    0.018 construction.py:425(dict_to_mgr)
#         6    0.000    0.000    0.000    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#         3    0.000    0.000    0.000    0.000 construction.py:470(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:483(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:486(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:494(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         3    0.000    0.000    0.000    0.000 construction.py:630(_sanitize_ndim)
#         1    0.000    0.000    0.000    0.000 construction.py:635(_extract_index)
#         3    0.000    0.000    0.000    0.000 construction.py:667(_sanitize_str_dtypes)
#         3    0.000    0.000    0.000    0.000 construction.py:687(_maybe_repeat)
#         3    0.000    0.000    0.000    0.000 construction.py:698(_try_cast)
#         1    0.001    0.001    1.150    1.150 covariance_generation.py:124(transform_cov_galactocentric)
#         1    0.001    0.001    0.785    0.785 covariance_generation.py:145(transform_cov_cylindirical)
#         2    1.193    0.597    1.892    0.946 covariance_generation.py:224(transform_cov_matrix)
#         4    0.000    0.000    0.000    0.000 dtypes.py:1206(is_dtype)
#         4    0.000    0.000    0.000    0.000 enum.py:792(value)
#         3    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#         2    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 frame.py:1693(to_numpy)
#         3    0.000    0.000    0.024    0.008 frame.py:3463(__getitem__)
#         1    0.000    0.000    0.000    0.000 frame.py:3923(_get_item_cache)
#         2    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#         3    0.000    0.000    0.018    0.006 frame.py:587(__init__)
#         2    0.000    0.000    0.000    0.000 function.py:49(__call__)
#         3    0.000    0.000    0.000    0.000 generic.py:239(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:328(attrs)
#         4    0.000    0.000    0.000    0.000 generic.py:349(flags)
#         2    0.000    0.000    0.022    0.011 generic.py:3609(take)
#         2    0.000    0.000    0.022    0.011 generic.py:3708(_take_with_is_copy)
#         2    0.000    0.000    0.000    0.000 generic.py:3925(_set_is_copy)
#       128    0.000    0.000    0.000    0.000 generic.py:43(_check)
#         6    0.000    0.000    0.000    0.000 generic.py:546(_get_axis_number)
#         2    0.000    0.000    0.000    0.000 generic.py:5517(__finalize__)
#         1    0.000    0.000    0.000    0.000 generic.py:5561(__getattr__)
#         6    0.000    0.000    0.000    0.000 generic.py:5577(__setattr__)
#         4    0.000    0.000    0.000    0.000 generic.py:560(_get_axis)
#         4    0.000    0.000    0.000    0.000 generic.py:5632(_protect_consolidate)
#         4    0.000    0.000    0.000    0.000 generic.py:5646(_consolidate_inplace)
#         4    0.000    0.000    0.000    0.000 generic.py:5650(f)
#         2    0.000    0.000    0.000    0.000 generic.py:566(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#         2    0.000    0.000    0.000    0.000 indexing.py:2323(convert_to_index_sliceable)
#         3    0.000    0.000    0.000    0.000 indexing.py:2486(check_deprecated_indexers)
#         6    0.000    0.000    0.000    0.000 inference.py:184(is_array_like)
#         9    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#         2    0.000    0.000    0.000    0.000 managers.py:1551(as_array)
#         2    0.000    0.000    0.000    0.000 managers.py:156(blknos)
#         5    0.000    0.000    0.000    0.000 managers.py:1675(is_consolidated)
#         3    0.000    0.000    0.000    0.000 managers.py:1683(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1689(<listcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:1693(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 managers.py:172(blklocs)
#         3    0.000    0.000    0.000    0.000 managers.py:1851(dtype)
#         1    0.000    0.000    0.000    0.000 managers.py:1862(internal_values)
#         1    0.000    0.000    0.018    0.018 managers.py:1951(create_block_manager_from_column_arrays)
#         3    0.000    0.000    0.000    0.000 managers.py:2006(_grouping_func)
#         1    0.000    0.000    0.018    0.018 managers.py:2022(_form_blocks)
#         2    0.018    0.009    0.018    0.009 managers.py:2074(_stack_arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:2151(_preprocess_slice_or_indexer)
#         4    0.000    0.000    0.000    0.000 managers.py:217(is_single_block)
#         4    0.000    0.000    0.000    0.000 managers.py:618(consolidate)
#         2    0.000    0.000    0.022    0.011 managers.py:634(reindex_indexer)
#         2    0.000    0.000    0.022    0.011 managers.py:710(_slice_take_blocks_ax0)
#         2    0.000    0.000    0.022    0.011 managers.py:872(take)
#         3    0.000    0.000    0.000    0.000 managers.py:916(__init__)
#         2    0.000    0.000    0.000    0.000 managers.py:970(from_blocks)
#         4    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#         8    0.000    0.000    0.000    0.000 missing.py:391(array_equivalent)
#         4    0.000    0.000    0.000    0.000 missing.py:911(clean_reindex_fill_method)
#        10    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#        14    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.001    0.001 numeric.py:149(ones)
#         9    0.000    0.000    0.000    0.000 numeric.py:289(full)
#         5    0.000    0.000    0.000    0.000 range.py:909(__len__)
#         4    0.000    0.000    0.000    0.000 re.py:250(compile)
#         4    0.000    0.000    0.000    0.000 re.py:289(_compile)
#         3    0.000    0.000    0.000    0.000 series.py:575(dtype)
#         1    0.000    0.000    0.000    0.000 series.py:687(_values)
#        14    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#        14    0.000    0.000    0.000    0.000 shape_base.py:348(_stack_dispatcher)
#        14    0.000    0.000    0.209    0.015 shape_base.py:357(stack)
#        14    0.000    0.000    0.000    0.000 shape_base.py:420(<listcomp>)
#        14    0.000    0.000    0.000    0.000 shape_base.py:424(<setcomp>)
#        14    0.000    0.000    0.000    0.000 shape_base.py:432(<listcomp>)
#         6    0.000    0.000    0.022    0.004 take.py:120(_take_nd_ndarray)
#         6    0.000    0.000    0.000    0.000 take.py:326(_get_take_nd_function)
#         6    0.000    0.000    0.000    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#         6    0.000    0.000    0.022    0.004 take.py:57(take_nd)
#         1    0.428    0.428    0.539    0.539 transformation_constants.py:128(get_jacobian_bayes)
#         1    0.058    0.058    0.159    0.159 transformation_constants.py:262(get_jacobian)
#         2    0.000    0.000    0.000    0.000 transformation_constants.py:46(get_A_matrix)
#         4    0.000    0.000    0.000    0.000 types.py:171(__get__)
#         8    0.000    0.000    0.000    0.000 typing.py:1375(cast)
#         2    0.000    0.000    0.000    0.000 utils.py:249(maybe_convert_indices)
#         4    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         4    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         4    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         4    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         4    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         9    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x5621f141b740}
#         6    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        12    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    1.937    1.937 {built-in method builtins.exec}
#       173    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        45    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#       472    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#    107/89    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        86    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        48    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#     38/24    0.210    0.006    0.210    0.009 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        19    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         2    0.002    0.001    0.002    0.001 {built-in method numpy.zeros}
#         4    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         2    0.021    0.011    0.021    0.011 {pandas._libs.algos.take_2d_axis0_float64_float64}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool_list}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        14    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}

# %%
from cupyx.profiler import benchmark
def my_func(C_icrs, data_array, z_0, r_0):

    galactocentric_cov = transform_cov_matrix_gpu(C_icrs, 
                                        data_array, 
                                        "Cartesian", 
                                        z_0=z_0, 
                                        r_0=r_0, 
                                        is_bayes=True)

    return galactocentric_cov

print(benchmark(my_func, (C_icrs,data_array, z_0, r_0 ,), n_repeat=1))
# Out:
# <class 'cupy.ndarray'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [78], line 13
#       4     galactocentric_cov = transform_cov_matrix_gpu(C_icrs,
#       5                                         data_array,
#       6                                         "Cartesian",
#       7                                         z_0=z_0,
#       8                                         r_0=r_0,
#       9                                         is_bayes=True)
#      11     return galactocentric_cov
# ---> 13 print(benchmark(my_func, (C_icrs,data_array, z_0, r_0 ,), n_repeat=1))
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupyx/profiler/_time.py:143, in benchmark(func, args, kwargs, n_repeat, name, n_warmup, max_duration, devices)
#     140 if not isinstance(devices, tuple):
#     141     raise ValueError('`devices` should be of tuple type')
# --> 143 return _repeat(
#     144     func, args, kwargs, n_repeat, name, n_warmup, max_duration, devices)
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupyx/profiler/_time.py:166, in _repeat(func, args, kwargs, n_repeat, name, n_warmup, max_duration, devices)
#     163 ev2 = _cupy.cuda.stream.Event()
#     165 for i in range(n_warmup):
# --> 166     func(*args, **kwargs)
#     168 for event, device in zip(events_1, devices):
#     169     prev_device = runtime.getDevice()
#
# Cell In [78], line 4, in my_func(C_icrs, data_array, z_0, r_0)
#       2 def my_func(C_icrs, data_array, z_0, r_0):
# ----> 4     galactocentric_cov = transform_cov_matrix_gpu(C_icrs,
#       5                                         data_array,
#       6                                         "Cartesian",
#       7                                         z_0=z_0,
#       8                                         r_0=r_0,
#       9                                         is_bayes=True)
#      11     return galactocentric_cov
#
# Cell In [70], line 173, in transform_cov_matrix_gpu(C, df, coordinate_system, z_0, r_0, is_bayes)
#     167 J_trunc= J.reshape(len(df),6,6, order = 'A').swapaxes(1,2)
#     169 # J_gpu = cp.asarray(J)
#     170 # J_trunc_gpu = cp.asarray(J_trunc)
#     171 # C_gpu = cp.asarray(C)
# --> 173 C_transformed_gpu = cp.matmul(cp.matmul(J, C), J_trunc)
#     174 #C_transformed_gpu = cp.matmul(C_transformed_gpu, J_trunc_gpu)
#     175
#     176 #C_transformed = J @ C @ J_trunc
#     178 return cp.asnumpy(C_transformed_gpu)
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/_core/_gufuncs.py:660, in _GUFunc.__call__(self, *args, **kwargs)
#     655 if len(input_coredimss) != len(args):
#     656     ValueError(
#     657         'According to `signature`, `func` requires %d arguments,'
#     658         ' but %s given' % (len(input_coredimss), len(args)))
# --> 660 args, dimsizess, loop_output_dims, outs, m_dims = self._get_args_transposed(  # NOQA
#     661     args, input_axes, outs, output_axes)
#     663 # The output shape varies depending on optional dims or not
#     664 # TODO(ecastill) this only works for one out argument
#     665 out_shape = [dimsizess[od][0] for od in loop_output_dims]
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/_core/_gufuncs.py:474, in _GUFunc._get_args_transposed(self, args, input_axes, outs, output_axes)
#     470 # we cant directly broadcast arrays together since their core dims
#     471 # might differ. Only the loop dimensions are broadcastable
#     472 shape = internal._broadcast_shapes(
#     473     [a.shape[:-len(self._input_coredimss)] for a in args])
# --> 474 args = [_manipulation.broadcast_to(
#     475     a, shape + a.shape[-len(self._input_coredimss):]) for a in args]
#     477 # Assess input args for loop dims
#     478 input_shapes = [a.shape for a in args]
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/_core/_gufuncs.py:474, in <listcomp>(.0)
#     470 # we cant directly broadcast arrays together since their core dims
#     471 # might differ. Only the loop dimensions are broadcastable
#     472 shape = internal._broadcast_shapes(
#     473     [a.shape[:-len(self._input_coredimss)] for a in args])
# --> 474 args = [_manipulation.broadcast_to(
#     475     a, shape + a.shape[-len(self._input_coredimss):]) for a in args]
#     477 # Assess input args for loop dims
#     478 input_shapes = [a.shape for a in args]
#
# TypeError: Argument 'array' has incorrect type (expected cupy._core.core._ndarray_base, got numpy.ndarray)

# %% [markdown]
# # Testing BinCollection

# %%
# # Generate bins
bin_collection = data_analysis.get_collapsed_bins(data = pandas_frame,
                                                      theta = (0, 1),
                                                      BL_r_min = 5000,
                                                      BL_r_max = 15000,
                                                      BL_z_min = -200,
                                                      BL_z_max = 200,
                                                      N_bins = (5, 1),
                                                      r_drift = False,
                                                      debug = False)

# %%
galactocentric_cov = cov.generate_galactocentric_covmat(icrs_data, 
                                                            is_bayes = True,
                                                            Z_0 = z_0,
                                                            R_0 = r_0)

cyl_cov = cov.transform_cov_cylindirical(galcen_data, 
                                             C = galactocentric_cov,
                                             Z_0 = z_0,
                                             R_0 = r_0)

galcen_data = galcen_data.merge(cyl_cov, on='source_id')

# # Generate bins
bin_collection = data_analysis.get_collapsed_bins(data = galcen_data,
                                                      theta = (0, 1),
                                                      BL_r_min = 5000,
                                                      BL_r_max = 15000,
                                                      BL_z_min = -200,
                                                      BL_z_max = 200,
                                                      N_bins = (5, 1),
                                                      r_drift = False,
                                                      debug = False)

# %%
galcen_data_trimmed = galcen_data[['r', 'z', 'v_r', 'v_phi',
       'source_id', 'sig_vphi', 'sig_vr']]

# %%
bin_collection = data_analysis.get_collapsed_bins(data = galcen_data,
                                                    theta = (0, 1),
                                                    BL_r_min = 5000,
                                                    BL_r_max = 15000,
                                                    BL_z_min = -200,
                                                    BL_z_max = 200,
                                                    N_bins = (5, 1),
                                                    r_drift = False,
                                                    debug = False)

# %%
galcen_data.shape
# Out:
# (37921, 11)

# %% [markdown]
# # Adimensional binning stuff

# %%
r_0 = 8277

galcen_data = data_analysis.get_transformed_data(icrs_data,
                                       include_cylindrical = True,
                                       z_0 = z_0,
                                       r_0 = r_0,
                                       v_sun = v_sun,
                                       debug = True,
                                       is_bayes = True,
                                       is_source_included = True)

galcen_data = galcen_data[(galcen_data.r < 15000) & (galcen_data.r > 5000)]
galcen_data = galcen_data[(galcen_data.z < 200) & (galcen_data.z > -200)]
galcen_data.reset_index(inplace=True, drop=True)

# %%
bin_collection_orig = data_analysis.get_collapsed_bins(data = galcen_data,
                                                    theta = (0, 1),
                                                    BL_r_min = 5000,
                                                    BL_r_max = 15000,
                                                    BL_z_min = -200,
                                                    BL_z_max = 200,
                                                    N_bins = (5, 1),
                                                    r_drift = False,
                                                    debug = False)

# %%
r_min = 5000/8277
print(r_min)
r_max = 15000/8277
print(r_max)
# Out:
# 0.6040836051709556
# 1.812250815512867

# %%
galcen_data['r_orig'] = galcen_data.r
galcen_data['r'] = galcen_data.r/8277

# %%
bin_collection_new = data_analysis.get_collapsed_bins(data = galcen_data,
                                                    theta = (0, 1),
                                                    BL_r_min = r_min,
                                                    BL_r_max = r_max,
                                                    BL_z_min = -200,
                                                    BL_z_max = 200,
                                                    N_bins = (5, 1),
                                                    r_drift = False,
                                                    debug = False)

# %% [markdown]
# # Bootstrapping

# %%
def bootstrap_weighted_error(bin_vphi, bin_sig_vphi):
    
    data_length = len(bin_vphi)
    idx_list = np.arange(data_length)
    bootstrapped_means = np.zeros(1000)

    for i in range(1000):
        rnd_idx = np.random.choice(idx_list, replace=True, size=data_length)
        test_sample = bin_vphi[rnd_idx]
        sig_vphi = bin_sig_vphi[rnd_idx]
        bootstrapped_means[i] = (test_sample/sig_vphi).sum()/(1/sig_vphi).sum()
    conf_int = np.percentile(bootstrapped_means, [16, 84])

    return (conf_int[1] - conf_int [0])/2

# %%
cp.random.Generator.random

# %%
def bootstrap_weighted_error_gpu(bin_vphi, bin_sig_vphi):
    
    total_num_it = 1000
    batch_num = 10
    data_length = len(bin_vphi)
    idx_list = cp.arange(data_length)
    bootstrapped_means = cp.zeros(total_num_it)



    for i in range(100):
        rnd_idx = cp.random.choice(idx_list, replace=True, size=(batch_num, data_length))

        test_sample = bin_vphi[rnd_idx]
        sig_vphi = bin_sig_vphi[rnd_idx]

        start_idx = (i+1)*batch_num - batch_num
        end_idx = (i+1)*batch_num

        bootstrapped_means[start_idx:end_idx] = (test_sample/sig_vphi).sum(axis=1)/(1/sig_vphi).sum(axis=1)
    conf_int = cp.percentile(bootstrapped_means, [16, 84])

    return (conf_int[1] - conf_int [0])/2

# %%
# Testing suggestions

def bootstrap_weighted_error_gpu(bin_vphi, bin_sig_vphi):
    
    total_num_it = 1000
    batch_num = 10
    data_length = len(bin_vphi)
    idx_list = cp.arange(data_length)
    bootstrapped_means = cp.zeros(total_num_it)

    for i in range(100):
        rnd_idx = cp.random.choice(idx_list, replace=True, size=(batch_num, data_length))

        test_sample = bin_vphi[rnd_idx]
        sig_vphi = bin_sig_vphi[rnd_idx]

        start_idx = (i+1)*batch_num - batch_num
        end_idx = (i+1)*batch_num

        bootstrapped_means[start_idx:end_idx] = cp.divide(cp.sum(cp.divide(test_sample,sig_vphi),axis=1), cp.sum(cp.divide(1,sig_vphi),axis=1))

        #bootstrapped_means[start_idx:end_idx] = (test_sample/sig_vphi).sum(axis=1)/(1/sig_vphi).sum(axis=1)
    conf_int = cp.percentile(bootstrapped_means, [16, 84])

    return (conf_int[1] - conf_int [0])/2

# %%
for i, bin in enumerate(bin_collection.bins):
    a = bootstrap_weighted_error_gpu(cp.asarray(bin.data.v_phi), 
                                    cp.asarray(bin.data.sig_vphi))
    print(a)
# Out:
# 0.08434672643578267
# 0.13636348952715593
# 0.09080084812264033
# 0.12972324922145617
# 0.3842372916217016

# %%
for i, bin in enumerate(bin_collection.bins):
    a = bootstrap_weighted_error_gpu(cp.asarray(bin.data.v_phi), 
                                    cp.asarray(bin.data.sig_vphi))
    print(a)
# Out:
# 0.08497365171838567
# 0.14790581196704977
# 0.09694302198889204
# 0.1303011019374054
# 0.39777704305015504

# %%
# Fully vectorised
def bootstrap_weighted_error_gpu(bin_vphi, bin_sig_vphi):
    
    num_it = 1000
    data_length = len(bin_vphi)
    idx_list = cp.arange(data_length)
    bootstrapped_means = cp.zeros(num_it)

    rnd_idx = cp.random.choice(idx_list, replace=True, size=(num_it, data_length))
    
    test_sample = bin_vphi[rnd_idx]
    sig_vphi = bin_sig_vphi[rnd_idx]
    bootstrapped_means = (test_sample/sig_vphi).sum(axis=1)/(1/sig_vphi).sum(axis=1)
    conf_int = cp.percentile(bootstrapped_means, [16, 84])

    return (conf_int[1] - conf_int [0])/2

# Fully vectorised
def bootstrap_weighted_error_cpu(bin_vphi, bin_sig_vphi):
    
    num_it = 2
    data_length = len(bin_vphi)
    idx_list = np.arange(data_length)
    bootstrapped_means = np.zeros(num_it)
    rnd_idx = np.random.choice(idx_list, replace=True, size=(num_it,data_length))

    print(rnd_idx.shape)
    print(bin_vphi.shape)

    test_sample = bin_vphi[rnd_idx]
    sig_vphi = bin_sig_vphi[rnd_idx]
    bootstrapped_means = (test_sample/sig_vphi).sum(axis=1)/(1/sig_vphi).sum(axis=1)
    conf_int = np.percentile(bootstrapped_means, [16, 84])

    return (conf_int[1] - conf_int [0])/2

# %%
# for i, bin in enumerate(bin_collection.bins):
    # a = bootstrap_weighted_error_cpu(bin.data.v_phi, 
    #                                 bin.data.sig_vphi)
    # print(a)

# %%
for i, bin in enumerate(bin_collection.bins):
    a = bootstrap_weighted_error_gpu(cp.asarray(bin.data.v_phi), 
                                    cp.asarray(bin.data.sig_vphi))
    print(a)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In [42], line 2
#       1 for i, bin in enumerate(bin_collection.bins):
# ----> 2     a = bootstrap_weighted_error_gpu(cp.asarray(bin.data.v_phi),
#       3                                     cp.asarray(bin.data.sig_vphi))
#       4     print(a)
#
# Cell In [41], line 8, in bootstrap_weighted_error_gpu(bin_vphi, bin_sig_vphi)
#       5 bootstrapped_means = cp.zeros(num_it)
#       7 # use the 'out' parameter to specify the output array directly
# ----> 8 rnd_idx = cp.random.choice(idx_list, replace=True, size=(num_it, data_length))
#      10 test_sample = bin_vphi[rnd_idx]
#      11 sig_vphi = bin_sig_vphi[rnd_idx]
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/random/_sample.py:190, in choice(a, size, replace, p)
#     160 """Returns an array of random values from a given 1-D array.
#     161
#     162 Each element of the returned array is independently sampled
#    (...)
#     187
#     188 """
#     189 rs = _generator.get_random_state()
# --> 190 return rs.choice(a, size, replace, p)
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/random/_generator.py:1082, in RandomState.choice(self, a, size, replace, p)
#    1080 if a_size == 0:  # TODO: (#4511) Fix `randint` instead
#    1081     a_size = 1
# -> 1082 index = self.randint(0, a_size, size=shape)
#    1083 # Align the dtype with NumPy
#    1084 index = index.astype(cupy.int64, copy=False)
#
# File ~/.gaia-project-env/lib/python3.9/site-packages/cupy/random/_generator.py:1170, in RandomState.randint(self, low, high, size, dtype)
#    1166     raise ValueError(
#    1167         'high is out of bounds for {}'.format(cupy.dtype(dtype).name))
#    1169 diff = hi1 - lo
# -> 1170 x = self._interval(diff, size).astype(dtype, copy=False)
#    1171 cupy.add(x, lo, out=x)
#    1172 return x
#
# File cupy/_core/core.pyx:516, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:575, in cupy._core.core._ndarray_base.astype()
#
# File cupy/_core/core.pyx:136, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:224, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:742, in cupy.cuda.memory.alloc()
#
# File cupy/cuda/memory.pyx:1419, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1440, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1120, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1141, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc()
#
# File cupy/cuda/memory.pyx:1379, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc()
#
# OutOfMemoryError: Out of memory allocating 3,168,148,480 bytes (allocated so far: 5,504,759,808 bytes).

# %%
for i, bin in enumerate(bin_collection.bins):
    a = bootstrap_weighted_error(cp.asarray(bin.data.v_phi), 
                                    cp.asarray(bin.data.sig_vphi))
    print(a)
# Out:
# 0.08398327623260116
# 0.1382662772271317
# 0.09862418241954174
# 0.1322435363425427
# 0.38986252724180304

# %%
def boot_func_gpu():
    for i, bin in enumerate(bin_collection.bins):
            a = bootstrap_weighted_error_gpu(cp.asarray(bin.data.v_phi), 
                                                cp.asarray(bin.data.sig_vphi))

# %%
def boot_func():
    for i, bin in enumerate(bin_collection.bins):
        a = bootstrap_weighted_error(bin.data.v_phi.to_numpy(), bin.data.sig_vphi.to_numpy())

# %%
cProfile.run('boot_func_gpu()')
# Out:
#          49684 function calls in 3.140 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.047    0.009    3.136    0.627 2088427909.py:1(bootstrap_weighted_error_gpu)
#         1    0.000    0.000    3.140    3.140 989478649.py:1(boot_func_gpu)
#      1375    0.001    0.000    0.003    0.000 <__array_function__ internals>:177(can_cast)
#      2395    0.002    0.000    0.005    0.000 <__array_function__ internals>:177(min_scalar_type)
#       500    0.000    0.000    0.007    0.000 <__array_function__ internals>:177(prod)
#         1    0.000    0.000    3.140    3.140 <string>:1(<module>)
#       500    0.013    0.000    3.035    0.006 _generator.py:1014(choice)
#       500    0.009    0.000    3.012    0.006 _generator.py:1146(randint)
#       500    0.001    0.000    0.001    0.000 _generator.py:1203(get_random_state)
#       500    0.027    0.000    2.991    0.006 _generator.py:645(_interval)
#       870    0.003    0.000    0.011    0.000 _generator.py:715(_curand_generate)
#       870    2.911    0.003    2.949    0.003 _generator.py:722(_get_indices)
#       880    0.001    0.000    0.001    0.000 _internal.py:250(__init__)
#       880    0.000    0.000    0.000    0.000 _internal.py:304(data)
#         5    0.000    0.000    0.000    0.000 _internal.py:863(npy_ctypes_check)
#       500    0.001    0.000    3.037    0.006 _sample.py:159(choice)
#      1870    0.000    0.000    0.001    0.000 abc.py:117(__instancecheck__)
#        30    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#        20    0.000    0.000    0.000    0.000 base.py:2481(is_categorical)
#        20    0.000    0.000    0.000    0.000 base.py:4987(__contains__)
#        30    0.000    0.000    0.000    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#         5    0.000    0.000    0.000    0.000 basic.py:196(zeros)
#      1750    0.009    0.000    0.009    0.000 basic.py:7(empty)
#        30    0.000    0.000    0.000    0.000 common.py:145(classes)
#        30    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#        30    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#        30    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#         5    0.000    0.000    0.000    0.000 compiler.py:709(is_valid_kernel_name)
#        10    0.000    0.000    0.000    0.000 count.py:4(count_nonzero)
#        10    0.000    0.000    0.000    0.000 frame.py:3463(__getitem__)
#        10    0.000    0.000    0.000    0.000 frame.py:3923(_get_item_cache)
#        15    0.000    0.000    0.004    0.000 from_data.py:49(asarray)
#       500    0.000    0.000    0.001    0.000 from_data.py:7(array)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:2965(_prod_dispatcher)
#       500    0.001    0.000    0.006    0.000 fromnumeric.py:2970(prod)
#       500    0.001    0.000    0.006    0.000 fromnumeric.py:69(_wrapreduction)
#       500    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        50    0.000    0.000    0.000    0.000 generic.py:5561(__getattr__)
#        30    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#      1000    0.001    0.000    0.001    0.000 getlimits.py:647(__init__)
#       500    0.000    0.000    0.000    0.000 getlimits.py:658(min)
#       500    0.000    0.000    0.000    0.000 getlimits.py:671(max)
#        10    0.000    0.000    0.000    0.000 indexing.py:2486(check_deprecated_indexers)
#        10    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#        10    0.000    0.000    0.000    0.000 managers.py:1862(internal_values)
#      1375    0.000    0.000    0.000    0.000 multiarray.py:498(can_cast)
#      2395    0.000    0.000    0.000    0.000 multiarray.py:613(min_scalar_type)
#      2750    0.002    0.000    0.004    0.000 numeric.py:1859(isscalar)
#         5    0.000    0.000    0.001    0.000 order.py:177(_quantile_unchecked)
#         5    0.027    0.005    0.027    0.005 order.py:287(_quantile_is_valid)
#         5    0.000    0.000    0.028    0.006 order.py:293(percentile)
#        20    0.000    0.000    0.000    0.000 ranges.py:30(<genexpr>)
#         5    0.000    0.000    0.000    0.000 ranges.py:9(arange)
#         5    0.000    0.000    0.000    0.000 re.py:188(match)
#         5    0.000    0.000    0.000    0.000 re.py:289(_compile)
#        10    0.000    0.000    0.000    0.000 series.py:687(_values)
#        10    0.000    0.000    0.000    0.000 series.py:825(__array__)
#       870    0.001    0.000    0.029    0.000 sumprod.py:141(cumsum)
#       880    0.000    0.000    0.000    0.000 syncdetect.py:27(_is_allowed)
#       880    0.000    0.000    0.001    0.000 syncdetect.py:36(_declare_synchronize)
#         5    0.000    0.000    0.000    0.000 transpose.py:5(rollaxis)
#      1870    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#       500    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    3.140    3.140 {built-in method builtins.exec}
#       530    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      6715    0.002    0.000    0.003    0.000 {built-in method builtins.isinstance}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       505    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       370    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         5    0.000    0.000    0.000    0.000 {built-in method cupy._core._routines_manipulation.rollaxis}
#       870    0.026    0.000    0.028    0.000 {built-in method cupy._core._routines_math.scan_core}
#         5    0.000    0.000    0.000    0.000 {built-in method cupy._core.core._internal_ascontiguousarray}
#       515    0.005    0.000    0.005    0.000 {built-in method cupy._core.core.array}
#       870    0.005    0.000    0.005    0.000 {built-in method cupy_backends.cuda.libs.curand.generate}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#      4270    0.006    0.000    0.012    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      1000    0.008    0.000    0.009    0.000 {method 'astype' of 'cupy._core.core._ndarray_base' objects}
#       500    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         5    0.000    0.000    0.000    0.000 {method 'flatten' of 'cupy._core.core._ndarray_base' objects}
#       510    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       500    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         5    0.000    0.000    0.000    0.000 {method 'memset_async' of 'cupy.cuda.memory.MemoryPointer' objects}
#       500    0.004    0.000    0.004    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       500    0.001    0.000    0.001    0.000 {method 'reshape' of 'cupy._core.core._ndarray_base' objects}
#         5    0.000    0.000    0.000    0.000 {method 'sort' of 'cupy._core.core._ndarray_base' objects}
#      1000    0.020    0.000    0.020    0.000 {method 'sum' of 'cupy._core.core._ndarray_base' objects}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}

# %%
cProfile.run('boot_func()')
# Out:
#          125959 function calls (125929 primitive calls) in 34.177 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   34.177   34.177 1894174980.py:1(boot_func)
#         5   14.655    2.931   34.177    6.835 493349493.py:1(bootstrap_weighted_error)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(any)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         5    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(percentile)
#     10000    0.009    0.000    0.093    0.000 <__array_function__ internals>:177(prod)
#        15    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(take)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(unique)
#         1    0.000    0.000   34.177   34.177 <string>:1(<module>)
#     10000    0.006    0.000    0.744    0.000 _methods.py:46(_sum)
#        20    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         5    0.000    0.000    0.000    0.000 arraysetops.py:125(_unpack_tuple)
#         5    0.000    0.000    0.000    0.000 arraysetops.py:133(_unique_dispatcher)
#         5    0.000    0.000    0.000    0.000 arraysetops.py:138(unique)
#         5    0.000    0.000    0.000    0.000 arraysetops.py:320(_unique1d)
#        10    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#        10    0.000    0.000    0.000    0.000 base.py:430(to_numpy)
#        20    0.000    0.000    0.000    0.000 base.py:4987(__contains__)
#        10    0.000    0.000    0.000    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#        10    0.000    0.000    0.000    0.000 blocks.py:354(dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:145(classes)
#        10    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#        10    0.000    0.000    0.000    0.000 common.py:1587(_is_dtype_type)
#        10    0.000    0.000    0.000    0.000 common.py:161(is_object_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#        10    0.000    0.000    0.000    0.000 frame.py:3463(__getitem__)
#        10    0.000    0.000    0.000    0.000 frame.py:3923(_get_item_cache)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2300(_any_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2305(any)
#     10000    0.001    0.000    0.001    0.000 fromnumeric.py:2965(_prod_dispatcher)
#     10000    0.012    0.000    0.077    0.000 fromnumeric.py:2970(prod)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#     10005    0.024    0.000    0.065    0.000 fromnumeric.py:69(_wrapreduction)
#     10005    0.004    0.000    0.004    0.000 fromnumeric.py:70(<dictcomp>)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:89(_take_dispatcher)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:93(take)
#         5    0.000    0.000    0.000    0.000 function_base.py:110(<lambda>)
#         5    0.000    0.000    0.000    0.000 function_base.py:111(<lambda>)
#         5    0.000    0.000    0.001    0.000 function_base.py:3651(_ureduce)
#         5    0.000    0.000    0.000    0.000 function_base.py:3856(_percentile_dispatcher)
#         5    0.000    0.000    0.001    0.000 function_base.py:3861(percentile)
#         5    0.000    0.000    0.001    0.000 function_base.py:4375(_quantile_unchecked)
#         5    0.000    0.000    0.000    0.000 function_base.py:4396(_quantile_is_valid)
#         5    0.000    0.000    0.000    0.000 function_base.py:4450(_get_gamma)
#         5    0.000    0.000    0.000    0.000 function_base.py:4472(_lerp)
#         5    0.000    0.000    0.001    0.000 function_base.py:4527(_quantile_ureduce_func)
#         5    0.000    0.000    0.000    0.000 function_base.py:4560(_get_indexes)
#         5    0.000    0.000    0.001    0.000 function_base.py:4595(_quantile)
#        10    0.000    0.000    0.000    0.000 generic.py:5561(__getattr__)
#        10    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#        10    0.000    0.000    0.000    0.000 indexing.py:2486(check_deprecated_indexers)
#        10    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#        10    0.000    0.000    0.000    0.000 managers.py:1851(dtype)
#        10    0.000    0.000    0.000    0.000 managers.py:1862(internal_values)
#         5    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        30    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#        15    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#        10    0.000    0.000    0.000    0.000 series.py:575(dtype)
#        10    0.000    0.000    0.000    0.000 series.py:687(_values)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   34.177   34.177 {built-in method builtins.exec}
#     10040    0.010    0.000    0.010    0.000 {built-in method builtins.getattr}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        80    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#        55    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
# 10035/10005    0.007    0.000    0.084    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         5    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#        15    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      5000   18.671    0.004   18.764    0.004 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#     10005    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     20020    0.763    0.000    0.763    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         5    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#     10000    0.011    0.000    0.755    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}

# %%
from numba import jit, config
type(config.DISABLE_JIT)
# Out:
# int

# %%
from numba import jit, config
config.DISABLE_JIT = True

if(config.DISABLE_JIT == False):
    NUMPY_LIB = np
# Out:
# True

# %%
import numba
import math

@numba.extending.register_jitable
def sin_func(x, sin):
    return sin(x)

@numba.njit
def foo(x, sin_wrapper):
    return sin_func(x, sin_wrapper)

def sin_wrapper(x):
    return math.sin(x)

# Call the foo function with the sin_wrapper function as an argument
result = foo(0.5, sin_wrapper)
print(result)  # Outputs: 0.479425538604203
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-21-3b7e2f516782> in <module>
#      14
#      15 # Call the foo function with the sin_wrapper function as an argument
# ---> 16 result = foo(0.5, sin_wrapper)
#      17 print(result)  # Outputs: 0.479425538604203
#
# ~/repos/dspn/dspn_env/lib64/python3.6/site-packages/numba/core/dispatcher.py in _compile_for_args(self, *args, **kws)
#     418                 e.patch_message(msg)
#     419
# --> 420             error_rewrite(e, 'typing')
#     421         except errors.UnsupportedError as e:
#     422             # Something unsupported is present in the user code, add help info
#
# ~/repos/dspn/dspn_env/lib64/python3.6/site-packages/numba/core/dispatcher.py in error_rewrite(e, issue_type)
#     359                 raise e
#     360             else:
# --> 361                 raise e.with_traceback(None)
#     362
#     363         argtypes = []
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# non-precise type pyobject
# During: typing of argument at <ipython-input-21-3b7e2f516782> (10)
#
# File "<ipython-input-21-3b7e2f516782>", line 10:
# def foo(x, sin_wrapper):
#     return sin_func(x, sin_wrapper)
#     ^
#
# This error may have been caused by the following argument(s):
# - argument 1: Cannot determine Numba type of <class 'function'>
